# %% [markdown]
# # Book Recommendation System - EDA

# %% [markdown]
# by: [Yachi Darji](https://www.linkedin.com/in/yachi-darji/)

# %% [markdown]
# Recommendation system now become an essential part of many internet platforms, like Netflix, YouTube, Amazon, etc. A recommendation system uses several algorithms to filter the data and makes the most relevant recommendations to users. The Recommendation System was originally used in 1979 in a program called Grundy, a computer-based librarian that suggested books for users to read. In this project, I tried to make a book recommendation system based on data from the Goodreads application. Goodreads is a social networking site that specializes in cataloging books. Goodreads was established with the goal of igniting interest in reading.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Goal:
# Design book recommendation system by several methods and explore the strengths and weaknesses of each method.

# %% [markdown]
# 1. How can we calculate similarity in two books? how to apply it to a recommendation engine?
# 2. How to predict rating for the book that user will give and haven't read by them?
# 3. Compare all methods with eachother. Overcome weakness.

# %% [markdown]
# ### Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

# %% [markdown]
# ### About Data

# %% [markdown]
# The dataset was scraped from Goodreads API in September 2017 by Zygmunt Zając.
# This dataset consists of 5 files:
#
# * rating.csv: contains user ratings for books they read
# * book_enriched.csv: contains metadata for each book(book ID, title,author, pages etc)
# * book_tag.csv: contains tags/shelves/genres assigned by users to books
# * tag.csv: contains the tag names corresponding to tag IDs in book_tag.csv
#
# Here, I will use rating.csv and the metadata of books.

# %%
ratings=pd.read_csv("C:/Users/yachi/final/myproject/Data/ratings.csv")

book=pd.read_csv("C:/Users/yachi/final/myproject/Data/books_enriched.csv")

# %% [markdown]
# ### 1. Rating

# %%
ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %% [markdown]
# * user_id: user identification number
# * book_id: book identification number
# * rating: rating given by user_id

# %%
ratings.shape
# Out:
# (5976479, 3)

# %%
for i in ratings.columns:
    print(f'NUMBER OF {i} is {ratings[i].nunique()}')
# Out:
# NUMBER OF user_id is 53424
# NUMBER OF book_id is 10000
# NUMBER OF rating is 5

# %% [markdown]
# There are 5976479 ratings given by 53424 unique user on 10000 books.

# %% [markdown]
# ### 2.Books

# %%
book.shape
# Out:
# (10000, 30)

# %%
book.head().T
# Out:
#                                                                            0  \
# Unnamed: 0                                                                 0
# index                                                                      0
# authors                                                  ['Suzanne Collins']
# average_rating                                                          4.34
# best_book_id                                                         2767052
# book_id                                                                    1
# books_count                                                              272
# description                WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# genres                     ['young-adult', 'fiction', 'fantasy', 'science...
# goodreads_book_id                                                    2767052
# image_url                  https://images.gr-assets.com/books/1447303603m...
# isbn                                                               439023483
# isbn13                                                       9780439023480.0
# language_code                                                            eng
# original_publication_year                                             2008.0
# original_title                                              The Hunger Games
# pages                                                                  374.0
# publishDate                                                         09/14/08
# ratings_1                                                              66715
# ratings_2                                                             127936
# ratings_3                                                             560092
# ratings_4                                                            1481305
# ratings_5                                                            2706317
# ratings_count                                                        4780653
# small_image_url            https://images.gr-assets.com/books/1447303603s...
# title                                The Hunger Games (The Hunger Games, #1)
# work_id                                                              2792775
# work_ratings_count                                                   4942365
# work_text_reviews_count                                               155254
# authors_2                                                ['Suzanne Collins']
#
#                                                                            1  \
# Unnamed: 0                                                                 1
# index                                                                      1
# authors                                    ['J.K. Rowling', 'Mary GrandPré']
# average_rating                                                          4.44
# best_book_id                                                               3
# book_id                                                                    2
# books_count                                                              491
# description                Harry Potter's life is miserable. His parents ...
# genres                     ['fantasy', 'fiction', 'young-adult', 'classics']
# goodreads_book_id                                                          3
# image_url                  https://images.gr-assets.com/books/1474154022m...
# isbn                                                               439554934
# isbn13                                                       9780439554930.0
# language_code                                                            eng
# original_publication_year                                             1997.0
# original_title                      Harry Potter and the Philosopher's Stone
# pages                                                                  309.0
# publishDate                                                         11/01/03
# ratings_1                                                              75504
# ratings_2                                                             101676
# ratings_3                                                             455024
# ratings_4                                                            1156318
# ratings_5                                                            3011543
# ratings_count                                                        4602479
# small_image_url            https://images.gr-assets.com/books/1474154022s...
# title                      Harry Potter and the Sorcerer's Stone (Harry P...
# work_id                                                              4640799
# work_ratings_count                                                   4800065
# work_text_reviews_count                                                75867
# authors_2                                  ['J.K. Rowling', 'Mary GrandPré']
#
#                                                                            2  \
# Unnamed: 0                                                                 2
# index                                                                      2
# authors                                                  ['Stephenie Meyer']
# average_rating                                                          3.57
# best_book_id                                                           41865
# book_id                                                                    3
# books_count                                                              226
# description                About three things I was absolutely positive.\...
# genres                     ['young-adult', 'fantasy', 'romance', 'fiction...
# goodreads_book_id                                                      41865
# image_url                  https://images.gr-assets.com/books/1361039443m...
# isbn                                                               316015849
# isbn13                                                       9780316015840.0
# language_code                                                            eng
# original_publication_year                                             2005.0
# original_title                                                      Twilight
# pages                                                                  501.0
# publishDate                                                         09/06/06
# ratings_1                                                             456191
# ratings_2                                                             436802
# ratings_3                                                             793319
# ratings_4                                                             875073
# ratings_5                                                            1355439
# ratings_count                                                        3866839
# small_image_url            https://images.gr-assets.com/books/1361039443s...
# title                                                Twilight (Twilight, #1)
# work_id                                                              3212258
# work_ratings_count                                                   3916824
# work_text_reviews_count                                                95009
# authors_2                                                ['Stephenie Meyer']
#
#                                                                            3  \
# Unnamed: 0                                                                 3
# index                                                                      3
# authors                                                       ['Harper Lee']
# average_rating                                                          4.25
# best_book_id                                                            2657
# book_id                                                                    4
# books_count                                                              487
# description                The unforgettable novel of a childhood in a sl...
# genres                     ['classics', 'fiction', 'historical-fiction', ...
# goodreads_book_id                                                       2657
# image_url                  https://images.gr-assets.com/books/1361975680m...
# isbn                                                                61120081
# isbn13                                                       9780061120080.0
# language_code                                                            eng
# original_publication_year                                             1960.0
# original_title                                         To Kill a Mockingbird
# pages                                                                  324.0
# publishDate                                                         05/23/06
# ratings_1                                                              60427
# ratings_2                                                             117415
# ratings_3                                                             446835
# ratings_4                                                            1001952
# ratings_5                                                            1714267
# ratings_count                                                        3198671
# small_image_url            https://images.gr-assets.com/books/1361975680s...
# title                                                  To Kill a Mockingbird
# work_id                                                              3275794
# work_ratings_count                                                   3340896
# work_text_reviews_count                                                72586
# authors_2                                                     ['Harper Lee']
#
#                                                                            4
# Unnamed: 0                                                                 4
# index                                                                      4
# authors                                              ['F. Scott Fitzgerald']
# average_rating                                                          3.89
# best_book_id                                                            4671
# book_id                                                                    5
# books_count                                                             1356
# description                Alternate Cover Edition ISBN: 0743273567 (ISBN...
# genres                     ['classics', 'fiction', 'historical-fiction', ...
# goodreads_book_id                                                       4671
# image_url                  https://images.gr-assets.com/books/1490528560m...
# isbn                                                               743273567
# isbn13                                                       9780743273560.0
# language_code                                                            eng
# original_publication_year                                             1925.0
# original_title                                              The Great Gatsby
# pages                                                                  200.0
# publishDate                                                         09/28/04
# ratings_1                                                              86236
# ratings_2                                                             197621
# ratings_3                                                             606158
# ratings_4                                                             936012
# ratings_5                                                             947718
# ratings_count                                                        2683664
# small_image_url            https://images.gr-assets.com/books/1490528560s...
# title                                                       The Great Gatsby
# work_id                                                               245494
# work_ratings_count                                                   2773745
# work_text_reviews_count                                                51992
# authors_2                                            ['F. Scott Fitzgerald']

# %% [markdown]
# In this dataset, there are 30 columns. However, after investigating them, there are several columns that are repeated. For example too many book_id columns, 2 title columns, 2 authors column, details of the number of reviews per rating for each book, etc. In order to make cleaner metadata, I will do data preprocessing.
#
# **Columns in dataset b**:<br>
# - Identification number related (`book_id`, `goodreads_book_id`, `best_book_id`, `work_id`, `isbn`, `isbn13`)
# - Title related (`original_title`, `title`)
# - Authors related (`authors`, `authors_2`)
# - Publication year related (`original_publication_year`, `publishDate`: the publication date)
# - Rating related (`average_rating`, `ratings_count`: number of review, `work_ratings_count`, `work_text_reviews_count`, `ratings_1`, `ratings_2`, `ratings_3`, `ratings_4`, `ratings_5`)
# - Image Url (`image_url`, `small_image_url`)
# - `books_count`: number of edition available
# - `language_code`: abbreviated language tags for all books
# - `genres`: the genre tags taken from the top shelves users have assigned to a book. Only the main Goodreads genres have been retained
# - `pages`: the total page count
# - `description`: a free text summarizing the book's content
# - Others (`Unnamed: 0`, `index`)

# %% [markdown]
# ### Statistical Summary

# %% [markdown]
# we can devide the columns to numerical columns and categorical columns then check statistics of data

# %%
#divide the columns to numerical and categorical value
nums = book.select_dtypes(include=[np.number]).columns
cats = book.select_dtypes(exclude=[np.number]).columns

# %%
for i in book.columns:
    print(f'NUMBER OF {i} is {book[i].nunique()}')
# Out:
# NUMBER OF Unnamed: 0 is 10000
# NUMBER OF index is 8770
# NUMBER OF authors is 5057
# NUMBER OF average_rating is 184
# NUMBER OF best_book_id is 10000
# NUMBER OF book_id is 10000
# NUMBER OF books_count is 597
# NUMBER OF description is 9772
# NUMBER OF genres is 4351
# NUMBER OF goodreads_book_id is 10000
# NUMBER OF image_url is 6669
# NUMBER OF isbn is 9300
# NUMBER OF isbn13 is 9153
# NUMBER OF language_code is 41
# NUMBER OF original_publication_year is 293
# NUMBER OF original_title is 9274
# NUMBER OF pages is 950
# NUMBER OF publishDate is 4679
# NUMBER OF ratings_1 is 2630
# NUMBER OF ratings_2 is 4117
# NUMBER OF ratings_3 is 6972
# NUMBER OF ratings_4 is 7762
# NUMBER OF ratings_5 is 8103
# NUMBER OF ratings_count is 9003
# NUMBER OF small_image_url is 6669
# NUMBER OF title is 9964
# NUMBER OF work_id is 10000
# NUMBER OF work_ratings_count is 9053
# NUMBER OF work_text_reviews_count is 4581
# NUMBER OF authors_2 is 5057

# %%
book[cats].describe().T
# Out:
#                  count unique  \
# authors          10000   5057
# description       9943   9772
# genres           10000   4351
# image_url        10000   6669
# isbn              9300   9300
# language_code    10000     41
# original_title    9415   9274
# publishDate       9992   4679
# small_image_url  10000   6669
# title            10000   9964
# authors_2        10000   5057
#
#                                                                top  freq
# authors                                           ['Stephen King']    58
# description      The first in a spectacularly genre-mashing adv...     4
# genres                                      ['fantasy', 'fiction']   152
# image_url        https://s.gr-assets.com/assets/nophoto/book/11...  3332
# isbn                                                     439023483     1
# language_code                                                  eng  9680
# original_title                                                         5
# publishDate                                     (None, None, None)    75
# small_image_url  https://s.gr-assets.com/assets/nophoto/book/50...  3332
# title                                               Selected Poems     4
# authors_2                                         ['Stephen King']    58

# %% [markdown]
# - The most popular author is Stephen King
# - Selected Poems appears 4 times. Is it the same book?
# - Because we already has `original_publication_year`, `publishDate` will be dropped
# - `authors`, `genres`, `publishDate`, and `authors_2` has unnecessary characters

# %%
# List of not unique value columns.
not_unique=['average_rating', 'books_count', 'original_publication_year', 'pages', 
                    'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'ratings_count', 
                    'work_ratings_count', 'work_text_reviews_count']

# %% [markdown]
# ### Univariate Analysis

# %%
# adjust the figure size for better readability
plt.figure(figsize=(12,6))

# plotting
features = not_unique
for i in range(0, len(features)):
    plt.subplot(2, 6, i+1)
    sns.boxplot(y=book[features[i]], color='skyblue')
    plt.tight_layout()

# %% [markdown]
# The data varies greatly, so there is no need to clean the outliers.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Missing value and Duplicated Rows

# %%
data=[book,ratings]
for i in data:
    print(i.isnull().values.any())
# Out:
# True
# False

# %%
data=[book,ratings]
for i in data:
    print(i.duplicated().values.any())
# Out:
# False
# False

# %% [markdown]
# There's no duplicate row in both data but we need to check missing value in book metadata

# %%
b=book.copy()

# %%
percent_missing=book.isnull().sum()*100/len(b)
missing_value=(pd.DataFrame({'percent_missing':percent_missing})).sort_values(by=['percent_missing'],ascending=False)
missing_value[missing_value['percent_missing']>0]
# Out:
#                            percent_missing
# isbn                                  7.00
# original_title                        5.85
# isbn13                                5.85
# pages                                 0.73
# description                           0.57
# original_publication_year             0.21
# publishDate                           0.08

# %% [markdown]
# * Impute `pages` with median.
# * Impute `original_publication_year` using `publishDate` .
# * Impute `description` using book's title.
# * Drop `isbn13`,`isbn`,`original_title`, there's no need to impute this

# %%
b[b['original_publication_year'].isnull()][['original_publication_year','publishDate']]
# Out:
#       original_publication_year           publishDate
# 198                         NaN     October 28th 2008
# 3249                        NaN     February 7th 2006
# 3881                        NaN   September 29th 2009
# 4252                        NaN    November 10th 2010
# 4303                        NaN        June 23rd 2009
# 4392                        NaN        April 8th 2013
# 5001                        NaN     November 9th 2004
# 5208                        NaN     December 6th 2010
# 5648                        NaN     October 11th 2006
# 7163                        NaN    November 25th 2004
# 7850                        NaN     October 15th 2007
# 8119                        NaN                  2009
# 8227                        NaN    ('6', '1', '1998')
# 8532                        NaN   ('11', '5', '2003')
# 8568                        NaN   ('11', '5', '2003')
# 9140                        NaN   ('10', '2', '2010')
# 9151                        NaN    ('2', '2', '2016')
# 9198                        NaN    ('9', '1', '2001')
# 9254                        NaN  (None, None, '2000')
# 9728                        NaN   ('9', '25', '2012')
# 9842                        NaN   ('6', '16', '2009')

# %% [markdown]
# * Get Year from `publishDate` and impute into `original_publication_year`

# %%
b['publishDate'].replace(r"[(')]","",regex=True,inplace=True)
b['publishDate']=b['publishDate'].str.extract('(\d{4})$').fillna('')

b['description']=b['description'].fillna(b['title'])

# %%
b['original_publication_year']=b['original_publication_year'].fillna(b['publishDate'])

# %%
b['year']=(b['original_publication_year']).astype(int)

# %%
b.drop('original_publication_year',axis=1,inplace=True)

# %%
# impute meadian values in page column

b['pages']=b['pages'].fillna(b['pages'].median())

# %%
#drop unnecessary cols
b=b.drop(['isbn','isbn13','original_title','publishDate'],axis=1)

# %%
b.isnull().values.any()
# Out:
# False

# %% [markdown]
# * Now we have no missing values

# %% [markdown]
# ### Feature engineering

# %%
# keeping important cols and drop rest ones.

imp=['small_image_url','book_id','title','authors','year','pages','description','genres','average_rating','ratings_count','books_count']
b=b[imp]

# %%
# Now display data column width to maximum.

with pd.option_context('display.max_colwidth',None):
    display(b.head())
# Out:
#                                               small_image_url  book_id  \
# 0  https://images.gr-assets.com/books/1447303603s/2767052.jpg        1
# 1        https://images.gr-assets.com/books/1474154022s/3.jpg        2
# 2    https://images.gr-assets.com/books/1361039443s/41865.jpg        3
# 3     https://images.gr-assets.com/books/1361975680s/2657.jpg        4
# 4     https://images.gr-assets.com/books/1490528560s/4671.jpg        5
#
#                                                       title  \
# 0                   The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# 2                                   Twilight (Twilight, #1)
# 3                                     To Kill a Mockingbird
# 4                                          The Great Gatsby
#
#                              authors  year  pages  \
# 0                ['Suzanne Collins']  2008  374.0
# 1  ['J.K. Rowling', 'Mary GrandPré']  1997  309.0
# 2                ['Stephenie Meyer']  2005  501.0
# 3                     ['Harper Lee']  1960  324.0
# 4            ['F. Scott Fitzgerald']  1925  200.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        WINNING MEANS FAME AND FORTUNE.LOSING MEANS CERTAIN DEATH.THE HUNGER GAMES HAVE BEGUN. . . .In the ruins of a place once known as North America lies the nation of Panem, a shining Capitol surrounded by twelve outlying districts. The Capitol is harsh and cruel and keeps the districts in line by forcing them all to send one boy and once girl between the ages of twelve and eighteen to participate in the annual Hunger Games, a fight to the death on live TV.Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. But Katniss has been close to dead before—and survival, for her, is second nature. Without really meaning to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love.
# 1  Harry Potter's life is miserable. His parents are dead and he's stuck with his heartless relatives, who force him to live in a tiny closet under the stairs. But his fortune changes when he receives a letter that tells him the truth about himself: he's a wizard. A mysterious visitor rescues him from his relatives and takes him to his new home, Hogwarts School of Witchcraft and Wizardry.After a lifetime of bottling up his magical powers, Harry finally feels like a normal kid. But even within the Wizarding community, he is special. He is the boy who lived: the only person to have ever survived a killing curse inflicted by the evil Lord Voldemort, who launched a brutal takeover of the Wizarding world, only to vanish after failing to kill Harry.Though Harry's first year at Hogwarts is the best of his life, not everything is perfect. There is a dangerous secret object hidden within the castle walls, and Harry believes it's his responsibility to prevent it from falling into evil hands. But doing so will bring him into contact with forces more terrifying than he ever could have imagined.Full of sympathetic characters, wildly imaginative situations, and countless exciting details, the first installment in the series assembles an unforgettable magical world and sets the stage for many high-stakes adventures to come.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    About three things I was absolutely positive.\r\n\r\nFirst, Edward was a vampire.\r\n\r\nSecond, there was a part of him—and I didn't know how dominant that part might be—that thirsted for my blood.\r\n\r\nAnd third, I was unconditionally and irrevocably in love with him.\r\n\r\nDeeply seductive and extraordinarily suspenseful, Twilight is a love story with bite.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it, To Kill A Mockingbird became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, To Kill A Mockingbird takes readers to the roots of human behavior - to innocence and experience, kindness and cruelty, love and hatred, humor and pathos. Now with over 18 million copies in print and translated into forty languages, this regional story by a young Alabama woman claims universal appeal. Harper Lee always considered her book to be a simple love story. Today it is regarded as a masterpiece of American literature.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Alternate Cover Edition ISBN: 0743273567 (ISBN13: 9780743273565)The Great Gatsby, F. Scott Fitzgerald's third book, stands as the supreme achievement of his career. This exemplary novel of the Jazz Age has been acclaimed by generations of readers. The story is of the fabulously wealthy Jay Gatsby and his new love for the beautiful Daisy Buchanan, of lavish parties on Long Island at a time when The New York Times noted "gin was the national drink and sex the national obsession," it is an exquisitely crafted tale of America in the 1920s.The Great Gatsby is one of the great classics of twentieth-century literature.(back cover)
#
#                                                                 genres  \
# 0  ['young-adult', 'fiction', 'fantasy', 'science-fiction', 'romance']
# 1                    ['fantasy', 'fiction', 'young-adult', 'classics']
# 2       ['young-adult', 'fantasy', 'romance', 'fiction', 'paranormal']
# 3         ['classics', 'fiction', 'historical-fiction', 'young-adult']
# 4             ['classics', 'fiction', 'historical-fiction', 'romance']
#
#    average_rating  ratings_count  books_count
# 0            4.34        4780653          272
# 1            4.44        4602479          491
# 2            3.57        3866839          226
# 3            4.25        3198671          487
# 4            3.89        2683664         1356

# %%
with pd.option_context('display.max_colwidth',None):
    display(b.head())
# Out:
#                                               small_image_url  book_id  \
# 0  https://images.gr-assets.com/books/1447303603s/2767052.jpg        1
# 1        https://images.gr-assets.com/books/1474154022s/3.jpg        2
# 2    https://images.gr-assets.com/books/1361039443s/41865.jpg        3
# 3     https://images.gr-assets.com/books/1361975680s/2657.jpg        4
# 4     https://images.gr-assets.com/books/1490528560s/4671.jpg        5
#
#                                                       title  \
# 0                   The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# 2                                   Twilight (Twilight, #1)
# 3                                     To Kill a Mockingbird
# 4                                          The Great Gatsby
#
#                              authors  year  pages  \
# 0                ['Suzanne Collins']  2008  374.0
# 1  ['J.K. Rowling', 'Mary GrandPré']  1997  309.0
# 2                ['Stephenie Meyer']  2005  501.0
# 3                     ['Harper Lee']  1960  324.0
# 4            ['F. Scott Fitzgerald']  1925  200.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        WINNING MEANS FAME AND FORTUNE.LOSING MEANS CERTAIN DEATH.THE HUNGER GAMES HAVE BEGUN. . . .In the ruins of a place once known as North America lies the nation of Panem, a shining Capitol surrounded by twelve outlying districts. The Capitol is harsh and cruel and keeps the districts in line by forcing them all to send one boy and once girl between the ages of twelve and eighteen to participate in the annual Hunger Games, a fight to the death on live TV.Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. But Katniss has been close to dead before—and survival, for her, is second nature. Without really meaning to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love.
# 1  Harry Potter's life is miserable. His parents are dead and he's stuck with his heartless relatives, who force him to live in a tiny closet under the stairs. But his fortune changes when he receives a letter that tells him the truth about himself: he's a wizard. A mysterious visitor rescues him from his relatives and takes him to his new home, Hogwarts School of Witchcraft and Wizardry.After a lifetime of bottling up his magical powers, Harry finally feels like a normal kid. But even within the Wizarding community, he is special. He is the boy who lived: the only person to have ever survived a killing curse inflicted by the evil Lord Voldemort, who launched a brutal takeover of the Wizarding world, only to vanish after failing to kill Harry.Though Harry's first year at Hogwarts is the best of his life, not everything is perfect. There is a dangerous secret object hidden within the castle walls, and Harry believes it's his responsibility to prevent it from falling into evil hands. But doing so will bring him into contact with forces more terrifying than he ever could have imagined.Full of sympathetic characters, wildly imaginative situations, and countless exciting details, the first installment in the series assembles an unforgettable magical world and sets the stage for many high-stakes adventures to come.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    About three things I was absolutely positive.\r\n\r\nFirst, Edward was a vampire.\r\n\r\nSecond, there was a part of him—and I didn't know how dominant that part might be—that thirsted for my blood.\r\n\r\nAnd third, I was unconditionally and irrevocably in love with him.\r\n\r\nDeeply seductive and extraordinarily suspenseful, Twilight is a love story with bite.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it, To Kill A Mockingbird became both an instant bestseller and a critical success when it was first published in 1960. It went on to win the Pulitzer Prize in 1961 and was later made into an Academy Award-winning film, also a classic.Compassionate, dramatic, and deeply moving, To Kill A Mockingbird takes readers to the roots of human behavior - to innocence and experience, kindness and cruelty, love and hatred, humor and pathos. Now with over 18 million copies in print and translated into forty languages, this regional story by a young Alabama woman claims universal appeal. Harper Lee always considered her book to be a simple love story. Today it is regarded as a masterpiece of American literature.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Alternate Cover Edition ISBN: 0743273567 (ISBN13: 9780743273565)The Great Gatsby, F. Scott Fitzgerald's third book, stands as the supreme achievement of his career. This exemplary novel of the Jazz Age has been acclaimed by generations of readers. The story is of the fabulously wealthy Jay Gatsby and his new love for the beautiful Daisy Buchanan, of lavish parties on Long Island at a time when The New York Times noted "gin was the national drink and sex the national obsession," it is an exquisitely crafted tale of America in the 1920s.The Great Gatsby is one of the great classics of twentieth-century literature.(back cover)
#
#                                                                 genres  \
# 0  ['young-adult', 'fiction', 'fantasy', 'science-fiction', 'romance']
# 1                    ['fantasy', 'fiction', 'young-adult', 'classics']
# 2       ['young-adult', 'fantasy', 'romance', 'fiction', 'paranormal']
# 3         ['classics', 'fiction', 'historical-fiction', 'young-adult']
# 4             ['classics', 'fiction', 'historical-fiction', 'romance']
#
#    average_rating  ratings_count  books_count
# 0            4.34        4780653          272
# 1            4.44        4602479          491
# 2            3.57        3866839          226
# 3            4.25        3198671          487
# 4            3.89        2683664         1356

# %% [markdown]
# * in our top rows we reported some unnecessary characters which arent supposed be in `description`column. we delete that characters and make all fonts in lowercase.

# %%
cols_trans=['authors','genres','description']
for i in cols_trans:
    b[i].replace(r"[\[\]\-\\\/\"—'()|:)]","",regex=True,inplace=True)
b['description'].replace({"\n":" ","isbn13" :"","isbn":"",r"[.,]":""},regex=True,inplace=True)
b['description']=b['description'].str.lower()
b['title']=b['title'].str.lower()

# %%
with pd.option_context('display.max_colwidth', None):
    display(b.sample(3))
# Out:
#                                                                              small_image_url  \
# 7620  https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png
# 2506                               https://images.gr-assets.com/books/1327886166s/187811.jpg
# 6563                                https://images.gr-assets.com/books/1406513762s/11430.jpg
#
#       book_id                                       title  \
# 7620     9173  the twentieth wife (taj mahal trilogy, #1)
# 2506     2684               shadowland (the mediator, #1)
# 6563     7654                     return (redemption, #3)
#
#                             authors  year  pages  \
# 7620                Indu Sundaresan  2002  380.0
# 2506                      Meg Cabot  2000  287.0
# 6563  Karen Kingsbury, Gary Smalley  2003  384.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                description  \
# 7620  an enchanting seventeenthcentury epic of grand passion and adventure this debut novel tells the captivating story of one of indias most legendary and controversial empresses  a woman whose brilliance and determination trumped myriad obstacles and whose love shaped the course of the mughal empireshe came into the world in the year 1577 to the howling accompaniment of a ferocious winter storm as the daughter of starving refugees fleeing violent persecution in persia her fateful birth in a roadside tent sparked a miraculous reversal of family fortune culminating in her fathers introduction to the court of emperor akbar she is called mehrunnisa the sun of women this is her storygrowing up on the fringes of emperor akbars opulent palace grounds mehrunnisa blossoms into a sapphireeyed child blessed with a precocious intelligence luminous beauty and a powerful ambition far surpassing the bounds of her familys station mehrunnisa first encounters young prince salim on his wedding day in that instant even as a royal gala swirls around her in celebration of the future emperors first marriage mehrunnisa foresees the path of her own destiny one day she decides with uncompromising surety she too will become salims wife she is all of eight years old  and wholly unaware of the great price she and her family will pay for this dreamskillfully blending the textures of historical reality with the rich and sensuous imaginings of a timeless fairy tale the twentieth wife sweeps readers up in the emotional pageant of salim and mehrunnisas embattled love firsttime novelist indu sundaresan charts her heroines enthralling journey across the years from an illfated first marriage through motherhood and into a dangerous maze of power struggles and political machinations through it all mehrunnisa and salim long with fiery intensity for the true redemptive love theyve never known  and their mutual quest ultimately takes them and the vast empire that hangs in the balance to places they never dreamed possibleshot through with wonder and suspense the twentieth wife is at once a fascinating portrait of one womans conventiondefying life behind the veil and a transporting saga of the astonishing potency of love
# 2506                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            suze is a mediator  a liaison between the living and the dead in other words she sees dead people and they wont leave her alone until she helps them resolve their unfinished business with the living but jesse the hot ghost haunting her bedroom doesnt seem to need her help which is a relief because suze has just moved to sunny california and plans to start fresh with trips to the mall instead of the cemetery and surfing instead of spectral visitations but the very first day at her new school suze realizes its not that easy theres a ghost with revenge on her mind  and suze happens to be in the way
# 6563                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                the redemption series won christian retailing’s 2005 retailer’s choice award for best series! this touching novel reunites readers with the baxter family and focuses on the only baxter son luke he is determined to leave his faith and his past behind and embrace a new freethinking future but what he doesn’t realize is that his past holds a secret even he doesn’t know when luke finds out his comfortable new life is turned upside down and he must turn back to his roots
#
#                                                                     genres  \
# 7620                                   historicalfiction, fiction, romance
# 2506  youngadult, fantasy, paranormal, romance, fiction, mystery, chicklit
# 6563                                           christian, fiction, romance
#
#       average_rating  ratings_count  books_count
# 7620            4.03           9873           37
# 2506            4.04          51580           58
# 6563            4.44          11737           30

# %% [markdown]
# ### EDA Question

# %% [markdown]
# #### 1. Distribution of ratings

# %%
#Rating distribution based on books
plt.figure(figsize=(6,4))
sns.histplot(b['average_rating'],kde=True)
plt.title('Distribution of Rating', weight='bold', fontsize =20)
plt.xlabel('average_rating', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.savefig('rating.png', dpi=600, bbox_inches="tight", format='png')
plt.show()



# Frequency for this

# %%
b.describe()
# Out:
#            book_id          year         pages  average_rating  ratings_count  \
# count  10000.00000  10000.000000  10000.000000    10000.000000   1.000000e+04
# mean    5000.50000   1982.040200    359.248800        4.002191   5.400124e+04
# std     2886.89568    152.420793    216.165717        0.254427   1.573700e+05
# min        1.00000  -1750.000000      0.000000        2.470000   2.716000e+03
# 25%     2500.75000   1990.000000    251.000000        3.850000   1.356875e+04
# 50%     5000.50000   2004.000000    336.000000        4.020000   2.115550e+04
# 75%     7500.25000   2011.000000    422.000000        4.180000   4.105350e+04
# max    10000.00000   2017.000000   5216.000000        4.820000   4.780653e+06
#
#         books_count
# count  10000.000000
# mean      75.712700
# std      170.470728
# min        1.000000
# 25%       23.000000
# 50%       40.000000
# 75%       67.000000
# max     3455.000000

# %% [markdown]
# * we admit that average rating is 4

# %% [markdown]
# #### 2. average rating per user

# %%
av_rating_user= ratings.groupby('user_id')['rating'].mean().reset_index()

plt.figure(figsize=(6,4))
sns.histplot(data=av_rating_user,x='rating',kde=True)
plt.title("Distribution of average rating per user")
plt.xlabel("Avereage rating given",fontsize=12)
plt.ylabel("Number of user",fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.savefig('ratingvscount.png', dpi=600, bbox_inches="tight", format='png')
plt.show()

# %% [markdown]
# #### 3. How many rating book usually get ?

# %%
av_rating_book= (ratings.groupby('book_id')['rating'].count().reset_index()).sort_values(by='rating',ascending=False)

plt.figure(figsize=(6,4))
sns.boxplot(data=av_rating_book.head(1000),x='rating')
plt.title("Distribution of average rating per book")
plt.xlabel("Avereage number of rating given",fontsize=12)
plt.ylabel("Number of book",fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
av_rating_book['rating'].describe()
# Out:
# count    10000.000000
# mean       597.647900
# std       1267.289788
# min          8.000000
# 25%        155.000000
# 50%        248.000000
# 75%        503.000000
# max      22806.000000
# Name: rating, dtype: float64

# %% [markdown]
# Minimum review is 8 while popular books may have 22k reviews. Gap is too large.

# %%
q3, q1 = np.percentile(av_rating_book, [75 ,25])
iqr = q3 - q1
maximum = q3 + (1.5 * iqr)
outlier_books = len(av_rating_book[av_rating_book['rating'] > maximum])
print(f'We have {outlier_books} books that are considered outlier, because they have more than {int(maximum)} number of ratings')
# Out:
# We have 26 books that are considered outlier, because they have more than 12515 number of ratings

# %% [markdown]
# #### 4. How many ratings does user usually give?

# %%
rating_per_user= (ratings.groupby('user_id')['rating'].count().reset_index()).sort_values(by='rating',ascending=False)

plt.figure(figsize=(6,4))
sns.distplot(rating_per_user['rating'])
plt.title("Distribution of No. of rating per user")
plt.xlabel("Average Number rating given",fontsize=12)
plt.ylabel("Number of book",fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

rating_per_user.to_csv('rating_per_user.csv')

# %%
rating_per_user['rating'].describe()
# Out:
# count    53424.000000
# mean       111.868804
# std         26.071224
# min         19.000000
# 25%         96.000000
# 50%        111.000000
# 75%        128.000000
# max        200.000000
# Name: rating, dtype: float64

# %% [markdown]
# At most people review 200 books and at least 19 books. The average person gives a review of 111 books. From 10,000 books in our dataset, even the user with the highest number of reviews managed to give a rating to only 2% of all of the books. Data in user is very sparse, so it will be better to use item-based collaborative filtering.

# %% [markdown]
# I also checked which user has the most reviews. I will use their user_id to test the recommendations.

# %%
rating_per_user[rating_per_user['rating'] == rating_per_user['rating'].max()]['user_id'].values
# Out:
# array([30944, 12874], dtype=int64)

# %% [markdown]
# #### 5. Does the rating count affect average rating?

# %%
# merge average rating and number of ratings for each sampeld individual
id_merged = av_rating_user.merge(rating_per_user, left_on="user_id", right_on="user_id")

#visualize
plt.figure(figsize=(10,10))
sns.scatterplot(x=id_merged['rating_y'], y=id_merged['rating_x'], color='#0047AB')
plt.title('Relationship of ratings count and average rating per user', weight='bold', fontsize=22)
plt.xlabel('Ratings count per user', fontsize=18)
plt.ylabel('Average rating per user', fontsize=18)
plt.axhline(y = 2, color = 'orangered', linestyle = '--')
plt.axvline(x = 
            50, color = 'orangered', linestyle = '--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig('ratingvscount.png', dpi=600, bbox_inches="tight", format='png')
plt.show()
# id_merged.to_csv('id_merged.csv')

# %% [markdown]
# - People who rate < 50 books tend to give higher ratings.
# - People start to give lower rating if they read more books.
# - This could be a result of an inappropriate book recommendation system, so that people end up reading books they don't like.

# %% [markdown]
# #### 6.Top - Rated books

# %%
# Top rated books
top_rated_books = b.sort_values(by='average_rating', ascending=False).head(10)

# Visualize it using barplot
plt.figure(figsize=(8, 8))
sns.barplot(data=top_rated_books, x='average_rating', y='title', palette='viridis')
plt.title('Top Rated Books', weight='bold', fontsize=20)
plt.xlabel('Average Rating', fontsize=18)
plt.ylabel('Book Title', fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('topRatedbg.png', dpi=600, bbox_inches="tight", format='png')
plt.show()
# top_rated_books.to_csv('top_rated_books.csv')

# %% [markdown]
# #### 8 Author with most books

# %%
auth_book_count=b.groupby('authors')['title'].count().sort_values(ascending=False)
auth_book_count.head()
# Out:
# authors
# Stephen King       60
# Nora Roberts       59
# Dean Koontz        46
# Terry Pratchett    42
# Agatha Christie    39
# Name: title, dtype: int64

# %% [markdown]
# Based in simple count, author with most books is Stephen King. However, in fact there are books written by more than one author, right?. So let's check them.

# %%
#Stephen King as an example

auth=[]
b.authors.apply(lambda x: auth.append(x) if 'Stephen King'in x else [])
auth
# Out:
# ['Stephen King',
#  'Stephen King, Bernie Wrightson',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King, Marie Milpois',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King, Ned Dameron',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King, Dave McKean',
#  'Stephen King, William Olivier Desmond',
#  'Stephen King, John D. MacDonald',
#  'Stephen King',
#  'Stephen King, Bettina Blanch Tyroller',
#  'Stephen King, Bernie Wrightson',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King, Darrel Anderson',
#  'Stephen King, Dominique Dill',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King, Peter Straub',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King, Jerry N. Uelsmann',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Roberto AguirreSacasa, Stephen King, Mike Perkins, Laura       Martin',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Peter David, Robin Furth, Jae Lee, Richard Isanove, Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King, Jae Lee',
#  'Stephen King',
#  'Stephen King, Peter Straub',
#  'Stephen King',
#  'Stephen King, Bernie Wrightson',
#  'Neil Gaiman, Mike Allred, Gary Amaro, Mark Buckingham, David Giordano, Tony Harris, Steve Leialoha, Vince Locke, Shea Anton Pensa, Alec Stevens, Bryan Talbot, John Watkiss, Todd Klein, Michael Zulli, Stephen King',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King, Willem Dafoe',
#  'Stephen King, Robin A.H. Waterfield',
#  'Richard Bachman, Stephen King',
#  'John Joseph Adams, Robert J. Sawyer, Stephen King, Michael Moorcock, Sharyn McCrumb, Stephen Baxter, Anne Perry, Barbara Hambly, Tanith Lee, Neil Gaiman, Rob Rogers, Naomi Novik, Anthony Burgess, Dominic Green, Laurie R. King, Barbara Roden, Peter Tremayne, Tim Lebbon, Bradley H. Sinor, Edward D. Hoch, Vonda N. McIntyre, Darrell Schweitzer, Mary Robinette Kowal, H.Paul Jeffers, Geoffrey A. Landis, Amy Myers, Tony Pi, Chris Roberson, Mark Valentine',
#  'Stephen King',
#  'Richard Bachman, Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Chris Van Allsburg, Lois Lowry, Kate DiCamillo, M.T. Anderson, Louis Sachar, Stephen King, Tabitha King, Jon Scieszka, Sherman Alexie, Gregory Maguire, Cory Doctorow, Jules Feiffer, Linda Sue Park, Walter Dean Myers, Lemony Snicket',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Stephen King',
#  'Roberto AguirreSacasa, Mike Perkins, Laura   Martin, Stephen King',
#  'Stephen King, Bernie Wrightson, Michele Wrightson',
#  'Stephen King',
#  'Scott Snyder, Stephen King, Rafael Albuquerque',
#  'Robin Furth, Stephen King, Peter Straub, Tony Shasteen, Nei Ruffino',
#  'Stephen King, Michael Whelan',
#  'Marc Guggenheim, Alex Maleev, Stephen King',
#  'Stephen King',
#  'Stephen King, Josh Hamilton']

# %% [markdown]
# Actually there are more than 1 author for many books. which would not be included into total books written by author. so  i decided to pick only first author to simplyfy the process.

# %%
prev_Count=b.authors.value_counts()['Stephen King']
print(f"Number of books written by Stephen King was {len(auth)} not {prev_Count}")
# Out:
# Number of books written by Stephen King was 97 not 60

# %%
# split authors if they have multiple authors listed
a=[]
b.authors.apply(lambda x:a.append(x) if ','in x else [])
a
# Out:
# ['J.K. Rowling, Mary GrandPré',
#  'Anne Frank, Eleanor Roosevelt, B.M. MooyaartDoubleday',
#  'Stieg Larsson, Reg Keeland',
#  'J.K. Rowling, Mary GrandPré, Rufus Beck',
#  'J.K. Rowling, Mary GrandPré',
#  'J.K. Rowling, Mary GrandPré',
#  'J.K. Rowling, Mary GrandPré',
#  'J.K. Rowling, Mary GrandPré',
#  'J.K. Rowling, Mary GrandPré',
#  'William Shakespeare, Robert           Jackson',
#  'Charlotte Brontë, Michael Mason',
#  'Mark Twain, John Seelye, Guy Cardwell',
#  'E.B. White, Garth Williams, Rosemary Wells',
#  'Emily Brontë, Richard J. Dunn',
#  'Jane Austen, Tony Tanner, Ros Ballaster',
#  'Louis Sachar, Louis Sachar',
#  'Homer, Robert Fagles, E.V. Rieu, Frédéric Mugler, Bernard Knox',
#  'Antoine de SaintExupéry, Richard Howard, Dom Marcos Barbosa, Melina Karakosta',
#  'Charles Dickens, Richard Maxwell, Hablot Knight Browne',
#  'Elie Wiesel, Marion Wiesel',
#  'Steven D. Levitt, Stephen J. Dubner',
#  'Gabriel García Márquez, Gregory Rabassa',
#  'Oscar Wilde, Jeffrey Eugenides',
#  'Bram Stoker, Nina Auerbach, David J. Skal',
#  'Stieg Larsson, Reg Keeland',
#  'Alexandre Dumas, Robin Buss',
#  'Victor Hugo, Lee Fahnestock, Norman MacAfee',
#  'Mitch Albom, Saulius Dagys',
#  'Mark Twain, Guy Cardwell, John Seelye',
#  'Vladimir Nabokov, Craig Raine',
#  'Gregory Maguire, Douglas Smith',
#  'William Shakespeare, Richard Andrews, Rex Gibson',
#  'Nathaniel Hawthorne, Thomas E. Connolly, Nina Baym',
#  'Stieg Larsson, Reg Keeland',
#  'Dr. Seuss, לאה נאור',
#  'Roald Dahl, Quentin Blake',
#  'Albert Camus, Matthew    Ward',
#  'Stephen King, Bernie Wrightson',
#  'Jane Austen, Fiona Stafford',
#  'Leo Tolstoy, Louise Maude, Leo Tolstoj, Aylmer Maude',
#  'Fyodor Dostoyevsky, David McDuff',
#  'Hermann Hesse, Hilda Rosner',
#  'Kami Garcia, Margaret Stohl',
#  'Roald Dahl, Quentin Blake',
#  'Alan Moore, Dave Gibbons, John Higgins',
#  'Herman Melville, Andrew Delbanco, Tom Quirk',
#  'Franz Kafka, Stanley Corngold',
#  'C.S. Lewis, Pauline Baynes',
#  'Emma McLaughlin, Nicola Kraus',
#  'Lewis Carroll, John Tenniel, Martin Gardner',
#  'Jane Austen, James Kinsley, Deidre Shauna Lynch',
#  'Gabriel García Márquez, Edith Grossman',
#  'P.C. Cast, Kristin Cast',
#  'William Shakespeare, Barbara A. Mowat, Paul Werstine, Catherine Belsey',
#  'Robert Galbraith, J.K. Rowling',
#  'Ayn Rand, Leonard Peikoff',
#  'Greg Mortenson, David Oliver Relin',
#  'Jane Carruth, Lewis Carroll, Rene Cloke',
#  'Carlos Ruiz Zafón, Lucia Graves',
#  'Daphne du Maurier, Sally Beauman',
#  'Laura Esquivel, Thomas  Christensen, Carol Christensen',
#  'Mario Puzo, Robert Thompson, Peter Bart',
#  'John Tiffany, Jack Thorne, J.K. Rowling',
#  'Terry Pratchett, Neil Gaiman',
#  'Ayn Rand, Leonard Peikoff',
#  'C.S. Lewis, Pauline Baynes',
#  'H.G. Wells, Greg Bear, Carlo Pagetti',
#  'Todd Burpo, Lynn Vincent',
#  'Neil Gaiman, Dave McKean',
#  'Cornelia Funke, Anthea Bell',
#  'Spencer Johnson, Kenneth H. Blanchard',
#  'Milan Kundera, Michael Henry Heim',
#  'Roald Dahl, Quentin Blake',
#  'Margaret Wise Brown, Clement Hurd',
#  'Homer, Robert Fagles, Frédéric Mugler, Bernard Knox',
#  'L. Frank Baum, W.W. Denslow',
#  'Hunter S. Thompson, Ralph Steadman',
#  'Lemony Snicket, Brett Helquist',
#  'Erich Maria Remarque, A.W. Wheen',
#  'Charles Dickens, George Cruikshank, Philip Horne',
#  'Alan Moore, David   Lloyd',
#  'Roald Dahl, Quentin Blake',
#  'Haruki Murakami, Jay Rubin',
#  'John Green, David Levithan',
#  'Arthur Miller, Christopher Bigsby',
#  'Robert Louis Stevenson, Vladimir Nabokov, Mervyn Peake, Dan Chaon',
#  'Patrick Süskind, John E. Woods',
#  'Sun Tzu, Thomas Cleary',
#  'Roald Dahl, Quentin Blake',
#  'Umberto Eco, William Weaver, Seán Barrett',
#  'Beatrice Sparks, Anonymous',
#  'John Kennedy Toole, Walker Percy',
#  'Haruki Murakami, Philip Gabriel',
#  'Stephen Hawking, Cao Chi, Phạm Văn Thiều',
#  'A.A. Milne, Ernest H. Shepard',
#  'P.C. Cast, Kristin Cast',
#  'Jane Austen, Alfred MacAdam',
#  'Laura Joffe Numeroff, Felicia Bond',
#  'Fredrik Backman, Henning Koch',
#  'Chuck Dixon, J.R.R. Tolkien, David Wenzel, Sean Deming',
#  'Newt Scamander, J.K. Rowling, Albus Dumbledore',
#  'Malala Yousafzai, Christina Lamb',
#  'Jane Austen, Kathryn Sutherland, Tony Tanner, Claire Lamont',
#  'Daniel Defoe, Gerald McCann, Virginia Woolf',
#  'Niccolò Machiavelli, Adolph Caso, Rufus Goodwin, Benjamin Martinez',
#  'Fyodor Dostoyevsky, Richard Pevear, Larissa Volokhonsky',
#  'P.C. Cast, Kristin Cast',
#  'Leo Tolstoy, Henry Gifford, Aylmer Maude, Louise Maude',
#  'Robert Kirkman, Tony Moore',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Corrie ten Boom, John Sherrill, Elizabeth Sherrill',
#  'J.M. Barrie, Michael Hague',
#  'Haruki Murakami, Jay Rubin',
#  'Jonathan Swift, Robert DeMaria Jr.',
#  'William Shakespeare, Barbara A. Mowat, Paul Werstine, Gail Kern Paster, Robert          Jackson',
#  'Unknown, Seamus Heaney',
#  'Frank Miller, David Mazzucchelli, Richmond Lewis, Dennis ONeil',
#  'Frances Hodgson Burnett, Nancy Bond',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Margery Williams Bianco, William   Nicholson',
#  'H.G. Wells, Arthur C. Clarke',
#  'Kenneth Branagh, William Shakespeare',
#  'Thomas Hardy, Tim Dolin, Margaret R. Higonnet',
#  'Gustave Flaubert, Margaret Mauldon, Malcolm Bowie, Mark Overstall',
#  'Norton Juster, Jules Feiffer',
#  'Frank Miller, Klaus Janson, Lynn Varley',
#  'Stephen King, Marie Milpois',
#  'Tsugumi Ohba, Takeshi Obata',
#  'Charles Dickens, Jeremy Tambling',
#  'Sherman Alexie, Ellen Forney',
#  'Mikhail Bulgakov, Katherine Tiernan OConnor, Diana Burgin, Ellendea Proffer',
#  'Kate DiCamillo, Chris Sheban',
#  'Miguel de Cervantes Saavedra, Roberto González Echevarría, John Rutherford',
#  'C.S. Lewis, Pauline Baynes',
#  'Richard Bach, Russell Munson',
#  'Robert Munsch, Sheila McGraw',
#  'J.R.R. Tolkien, Christopher Tolkien, Ted Nasmith',
#  'Franz Kafka, Edwin Muir, Willa Muir, Max Brod',
#  'Arthur Conan Doyle, Anne Perry',
#  'Jon Scieszka, Lane Smith',
#  'Paulo Coelho, Margaret Jull Costa',
#  'Sheryl Sandberg, Nell Scovell',
#  'Jostein Gaarder, Paulette Møller',
#  'Johanna Spyri, Angelo  Rinaldi, Beverly Cleary',
#  'P.C. Cast, Kristin Cast',
#  'Geoffrey Chaucer, Nevill Coghill',
#  'Haruki Murakami, Jay Rubin, Philip Gabriel',
#  'Gaston Leroux, Alexander Teixeira de Mattos',
#  'Judith Viorst, Ray Cruz',
#  'Isabel Allende, Magda Bogin',
#  'Agatha Christie, Ροζίτα Σώκου',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Robert Galbraith, J.K. Rowling',
#  'Jules Verne, Anthony Bonner',
#  'Virginia Woolf, Maureen Howard',
#  'Richard Bachman, Stephen King',
#  'Jules Verne, Michael Glencross, Brian W. Aldiss',
#  'Paulo Coelho, Margaret Jull Costa',
#  'Stephen King, Ned Dameron',
#  'Bernhard Schlink, Carol Brown Janeway',
#  'Bill Martin Jr., Eric Carle',
#  'Alan Moore, Brian Bolland, Tim Sale',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Malcolm X, Alex Haley',
#  'Neil Gaiman, Sam Kieth, Mike Dringenberg, Malcolm Jones III, Todd Klein, Karen  Berger',
#  'William Shakespeare, Roma Gill',
#  'Plato, Desmond Lee',
#  'Victor Hugo, Walter J. Cobb',
#  'Bill Watterson, G.B. Trudeau',
#  'P.C. Cast, Kristin Cast',
#  'Irvine Welsh, Eric Lindor Fall',
#  'Jacob Grimm, Wilhelm Grimm, Josef Scharl, Padraic Colum, Joseph Campbell, Margaret Raine Hunt, James Stern',
#  'Francis Chan, Danae Yankoski, Chris Tomlin',
#  'Natsuki Takaya, Alethea Nibley, Athena Nibley',
#  'P.C. Cast, Kristin Cast',
#  'Stephen King, Dave McKean',
#  'Aldous Huxley, Christopher Hitchens',
#  'P.C. Cast, Kristin Cast',
#  'Stephen King, William Olivier Desmond',
#  'Sophocles, J.E. Thomas',
#  'Kenneth Grahame, Gillian Avery',
#  'Marjane Satrapi, Mattias Ripa',
#  'Masashi Kishimoto, Katy Bridges',
#  'William Shakespeare, Robert          Jackson, Barbara A. Mowat, Paul Werstine',
#  'Bill Martin Jr., John Archambault, Lois Ehlert',
#  'George Orwell, Christopher Hitchens',
#  'Paul Kalanithi, Abraham Verghese',
#  'Sam McBratney, Anita Jeram',
#  'Stephen King, John D. MacDonald',
#  'Astrid Lindgren, Lauren Child, Florence Lamborn, Nancy Seligsohn',
#  'Muriel Barbery, Alison Anderson',
#  'Doris Kearns Goodwin, Suzanne Toren',
#  'Albert Camus, Stuart Gilbert',
#  'Lemony Snicket, Brett Helquist',
#  'Michael Ende, Ralph Manheim, Roswitha Quadflieg',
#  'Upton Sinclair, Earl Lee, Kathleen DeGrave',
#  'Hiromu Arakawa, Akira Watanabe',
#  'Edith Wharton, Maureen Howard',
#  'Judi Barrett, Ron Barrett',
#  'Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker',
#  'Stephen King, Bettina Blanch Tyroller',
#  'Marie Kondō, Cathy Hirano',
#  'Jennifer Niven, فرانک معنوی',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Stephen King, Bernie Wrightson',
#  'James Joyce, Seamus Deane',
#  'Robert Jordan, Brandon Sanderson',
#  'George Eliot, Michel Faber',
#  'Marcus Pfister, J. Alison James',
#  'Vincent Bugliosi, Curt Gentry',
#  'Dante Alighieri, Anthony M. Esolen',
#  'John Milton, John      Leonard',
#  'Robert Jordan, Brandon Sanderson',
#  'Jason Fried, David Heinemeier Hansson',
#  'Stephenie Meyer, Ilyana Kadushin, Matt Walters',
#  'Jon Stone, Michael J. Smollin',
#  'Chris Kyle, Scott McEwen, Jim DeFelice',
#  'Hermann Hesse, Basil Creighton',
#  'Kate DiCamillo, Timothy Basil Ering',
#  'Barbara Kingsolver, Steven L. Hopp, Camille Kingsolver, Richard A. Houser',
#  'Brian K. Vaughan, Fiona Staples',
#  'Lemony Snicket, Brett Helquist',
#  'Seth GrahameSmith, Jane Austen',
#  'Fyodor Dostoyevsky, Constance Garnett, Alan Myers, Joseph Frank, Anna Brailovsky',
#  'Aziz Ansari, Eric Klinenberg',
#  'Katherine Applegate, Patricia Castelao',
#  'Stephen King, Darrel Anderson',
#  'Wilkie Collins, Matthew Sweet',
#  'Steven D. Levitt, Stephen J. Dubner',
#  'William Makepeace Thackeray, John Carey',
#  'Stephen King, Dominique Dill',
#  'Bill Willingham, Lan Medina, Steve Leialoha, Craig Hamilton, James Jean',
#  'Thomas Hardy, Rosemarie Morgan, Shannon Russell',
#  'P.C. Cast, Kristin Cast',
#  'Jon Stewart, Ben Karlin, David Javerbaum, Rich Bloomquist, Steve Bodow, Tim Carvell, Eric Drysdale, J.R. Havlan, Scott Jacobson, Tom Johnson, Rob Kutner, Chris Regan, Jason Reich, Jason Ross, Stephen Colbert, Samantha Bee, Rob Corddry, Brendan Hay, Ed Helms',
#  'Don Piper, Cecil Murphey',
#  'Lao Tzu, GiaFu Feng, Jane English, Chungliang Al Huang, Rowena Pattee Kryder, Toinette Lippe',
#  'Hans Christian Andersen, Lily Owens, Arthur Rackham, Hans Richter',
#  'Friedrich Nietzsche, Walter Kaufmann',
#  'Elizabeth Gaskell, Alan Shelston',
#  'Aesop, Laura Harris, Laura Gibbs',
#  'Matsuri Hino, Tomo Kimura',
#  'Anne McCaffrey, Teodor Panasiński',
#  'James Joyce, Jeri Johnson',
#  'Kami Garcia, Margaret Stohl',
#  'Stephen Colbert, Richard Dahm, Paul Dinello, Allison Silverman, Michael Brumm, Eric Drydale, Rob Dubbin, Glenn Eichler, Peter Grosz, Peter Gwinn, Jay Katsir, Laura Krafft, Frank Lesser, Tom Purcell',
#  'Kenneth H. Blanchard, Spencer Johnson',
#  'Lemony Snicket, Brett Helquist',
#  'J. Lynn, Jennifer L. Armentrout',
#  'Dante Alighieri, Allen Mandelbaum, Eugenio Montale',
#  'Benjamin Hoff, Ernest H. Shepard',
#  'David Lagercrantz, Stieg Larsson, George Goulding',
#  'Mark Twain, Everett H. Emerson',
#  'Elif Shafak, إليف شافاق, ارسلان فصیحی, محمد درويش',
#  'Hajime Isayama, Sheldon Drzka',
#  'Elena Ferrante, Ann Goldstein',
#  'Andrew Clements, Brian Selznick',
#  'Brian K. Vaughan, Pia Guerra, José Marzán Jr.',
#  'Anne Tyler, Jennifer Bassett',
#  'Haruki Murakami, Alfred Birnbaum',
#  'Paulo Coelho, Alan R. Clarke',
#  'Johann David Wyss, Scott McKowen, Arthur Pober',
#  'Watty Piper, Doris Hauman, George Hauman',
#  'E.B. White, Garth Williams',
#  'Lemony Snicket, Brett Helquist',
#  'Janet Evanovich, Lorelei King',
#  'Lemony Snicket, Brett Helquist',
#  'Gabriel García Márquez, Gregory Rabassa',
#  'Ronald Holt, Arthur Conan Doyle',
#  'Bill OReilly, Martin Dugard',
#  'Stephen King, Peter Straub',
#  'P.L. Travers, Mary Shepard',
#  'Roald Dahl, Quentin Blake',
#  'James Patterson, Peter de Jonge',
#  'Haruki Murakami, Philip Gabriel',
#  'Clement C. Moore, Jan Brett',
#  'Virgil, Robert Fitzgerald',
#  'Haruki Murakami, Jay Rubin',
#  'Kennilworthy Whisp, J.K. Rowling',
#  'Harry Allard, James  Marshall',
#  'Richard Bachman, Stephen King',
#  'Lemony Snicket, Brett Helquist',
#  'Stephen King, Jerry N. Uelsmann',
#  'Gertrude Chandler Warner, L. Kate Deal',
#  'Arthur Conan Doyle, Kyle Freeman',
#  'Eiichirō Oda, Andy Nakatani',
#  'Allen Ginsberg, William Carlos Williams',
#  'Anonymous, Joseph Smith Jr.',
#  'Yana Toboso, Tomo Kimura',
#  'Robert Louis Stevenson, Robert Mighall',
#  'Fyodor Dostoyevsky, Andrew R. MacAndrew, Ben Marcus',
#  'Robert Jordan, Brandon Sanderson',
#  'James Patterson, Andrew Gross',
#  'Faye Perozich, Anne Rice, John Bolton, Daerick Gröss',
#  'Louis Sachar, Adam McCauley',
#  'Dalai Lama XIV, Howard C. Cutler',
#  'L.J. Smith, Kevin Williamson, Julie Plec',
#  'Cornelia Funke, Anthea Bell',
#  'Margaret Weis, Tracy Hickman',
#  'Jon Scieszka, Lane Smith',
#  'Marcus Luttrell, Patrick Robinson',
#  'Roberto AguirreSacasa, Stephen King, Mike Perkins, Laura       Martin',
#  'Jeff Smith, Steve Hamaker',
#  'Kami Garcia, Margaret Stohl, Paz Pruneda',
#  'Karl Marx, Friedrich Engels, Gareth Stedman Jones',
#  'Julia Child, Alex PrudHomme',
#  'Travis Bradberry, Jean Greaves, Patrick Lencioni',
#  'Douglas Preston, Lincoln Child',
#  'Nicola Yoon, David Yoon',
#  'Marjane Satrapi, Mattias Ripa, Blake Ferris, Anjali Singh',
#  'Irving Stone, שמואל שניצר',
#  'أحلام مستغانمي, Ahlam Mosteghanemi',
#  'Lemony Snicket, Brett Helquist',
#  'Charles Dickens, Nicola Bradbury, Hablot Knight Browne',
#  'Lewis Carroll, John Tenniel, Peter Glassman',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Guillermo del Toro, Chuck Hogan',
#  'Emily Dickinson, Thomas H. Johnson',
#  'Mary Norton, Beth Krush, Joe Krush',
#  'Haruki Murakami, Alfred Birnbaum',
#  'Paulo Coelho, Margaret Jull Costa',
#  'Edith Wharton, Nina Bawden',
#  'Hiro Mashima, William Flanagan',
#  'Patrick Rothfuss, Nate  Taylor',
#  'Aleksandr Solzhenitsyn, H.T. Willetts',
#  'Sophocles, J.E. Thomas',
#  'A.A. Milne, Ernest H. Shepard',
#  'Lemony Snicket, Brett Helquist',
#  'Boris Pasternak, Max Hayward, Manya Harari, John Bayley',
#  'Jane Hamilton, Frank  Muller, C.J. Critt',
#  'O. Henry, Lisbeth Zwerger',
#  'William S. Burroughs, James Grauerholz, Barry  Miles',
#  'Neil Gaiman, Kelley Jones, Charles Vess, Colleen Doran, Malcolm Jones III, Steve Erickson',
#  'Ursula K. Le Guin, Lech Jęczmyk',
#  'John Green, Maureen Johnson, Lauren Myracle',
#  'Henrik Ibsen, Michael   Meyer',
#  'Rachel Cohn, David Levithan',
#  'Beth Hoffman, Jenna Lamia',
#  'Munro Leaf, Robert Lawson',
#  'Nora Roberts, MacLeod Andrews',
#  'Haruki Murakami, Philip Gabriel',
#  'Andre Agassi, J.R. Moehringer',
#  'Lee Child, Dick Hill',
#  'Francine Rivers, Richard Ferrone',
#  'Jeph Loeb, Tim Sale, Gregory Wright, Richard Starkings',
#  'JeanPaul Sartre, Lloyd Alexander, Hayden Carruth',
#  'Arthur Conan Doyle, Peter Ackroyd, Ed Glinert',
#  'Doreen Cronin, Betsy Lewin',
#  'Terry Goodkind, Dick Hill',
#  'Janette Sebring Lowrey, Gustaf Tenggren',
#  'Patrick deWitt, Marcelo Barbão',
#  'Roald Dahl, Quentin Blake',
#  'Paulo Coelho, Montserrat Mira',
#  'William Shakespeare, Katherine DuncanJones',
#  'Ron Hall, Denver Moore, Lynn Vincent',
#  'D.H. Lawrence, Doris Lessing, Chester Brown',
#  'David Eddings, Leigh Eddings',
#  'Elizabeth Strout, Goran Skrobonja',
#  'Greg Behrendt, Liz Tuccillo',
#  'Rudyard Kipling, Alev Lytle Croutier',
#  'John Eldredge, Stasi Eldredge',
#  'Peter David, Robin Furth, Jae Lee, Richard Isanove, Stephen King',
#  'Jay Crownover, Charlotte Connan de vries',
#  'Haruki Murakami, Philip Gabriel',
#  'Edgar Allan Poe, Stephen Marlowe',
#  'Edgar Allan Poe, Benjamin F. Fisher',
#  'Lewis Carroll, John Tenniel',
#  'M.C. Escher, Bruce Brooks Pfeiffer',
#  'James Patterson, Maxine Paetro',
#  'Anne Brontë, Stevie Davies',
#  'Walter Farley, Keith Ward',
#  'Lemony Snicket, Brett Helquist',
#  'David Bayles, Ted Orland',
#  'Henry James, Patricia Crick',
#  'Edgar Allan Poe, Gustave Doré',
#  'Richard Bachman, Stephen King',
#  'Philip K. Dick, David Alabort, Manuel Espín',
#  'Miep Gies, Alison Leslie Gold',
#  'Michael Bond, Peggy Fortnum',
#  'Lemony Snicket, Brett Helquist',
#  'Paulo Coelho, Amanda Hopkinson, Nick Caistor',
#  'Audrey Penn, Ruth E. Harper, Nancy M. Leak',
#  'James Patterson, Gabrielle Charbonnet',
#  'Anthony Kiedis, Larry Sloman',
#  'Margaret Atwood, Brigitte Walitzek',
#  'Gabriel García Márquez, Edith Grossman',
#  'James Patterson, Andrew Gross',
#  'Kerstin Gier, Anthea Bell',
#  'Oliver Pötzsch, Lee Chadeayne',
#  'Patricia C. Wrede, Peter de Sève',
#  'William Strunk Jr., E.B. White',
#  'Larry Niven, Jerry Pournelle',
#  'Jo Nesbø, Don Bartlett',
#  'John  Williams, John McGahern',
#  'David Cote, Stephen Schwartz, Joan Marcus, Winnie Holzman',
#  'Garth Ennis, Steve Dillon, Joe R. Lansdale',
#  'Edmond Rostand, Eteel Lawson, Lowell Bair',
#  'Neil Gaiman, Steve Parkhouse, Chris Bachalo, Michael Zulli, Mike Dringenberg, Malcolm Jones III, Todd Klein, Clive Barker',
#  'Anonymous, Richard Francis Burton, A.S. Byatt',
#  'Beverly Cleary, Louis Darling, Tracy Dockray',
#  'Rachel Cohn, David Levithan',
#  'Laura Joffe Numeroff, Felicia Bond',
#  'Roald Dahl, Quentin Blake',
#  'Laura Joffe Numeroff, Felicia Bond',
#  'Mike Mignola, John Byrne',
#  'Alexandre Dumas, Francine du Plessix Gray, Joachim Neugroschel',
#  'Shirley Jackson, Laura   Miller',
#  'Laura Ingalls Wilder, Garth Williams',
#  'P.C. Cast, Kristin Cast',
#  'Marcus Aurelius, Martin Hammond, Diskin Clay',
#  'Dave Barry, Ridley Pearson, Greg Call',
#  'Lemony Snicket, Brett Helquist',
#  'Lemony Snicket, Brett Helquist',
#  'Margaret Wise Brown, Clement Hurd',
#  'Stephen Hawking, Leonard Mlodinow',
#  'Richard Bachman, Stephen King',
#  'JanPhilipp Sendker, Kevin Wiliarty',
#  'Carlo Collodi, John Boyne, Monteiro Lobato, Unknown',
#  'Leo Tolstoy, Aylmer Maude',
#  'Albert Camus, Justin OBrien',
#  'Wilkie Collins, Carolyn G. Heilbrun',
#  'Italo Calvino, William Weaver',
#  'Sophocles, Dudley Fitts, Elena Bono, Robert Fitzgerald',
#  'Fredrik Backman, Henning Koch',
#  'Kate DiCamillo, Bagram Ibatoulline',
#  'Anonymous, N.K. Sandars',
#  'Janet Evanovich, Lorelei King',
#  'Yoshiki Nakamura, Tomo Kimura',
#  'J.K. Rowling, Mary GrandPré',
#  'Oscar Wilde, Richard Allen Cave',
#  'Irène Némirovsky, Sandra Smith',
#  'Vincent van Gogh, Ronald de Leeuw, Mark Roskill, Arnold J. Pomerans',
#  'Grant Morrison, Dave McKean',
#  'V.E. Schwab, Victoria Schwab',
#  'Roald Dahl, Quentin Blake',
#  'Ivan Turgenev, George Reavy, Jane Costlow',
#  'Eliyahu M. Goldratt, Jeff Cox',
#  'Homer, Robert Fagles, Bernard Knox',
#  'Mark Waid, Alex Ross, Elliot S. Maggin',
#  'Chris Colfer, Brandon Dorman',
#  'Charlotte Perkins Gilman, Elaine Hedges',
#  'Peter Thiel, Blake  Masters',
#  'Charles Dickens, Katharine Kroeber Wiley',
#  'Dr. Seuss, Various',
#  'Nikolai Gogol, Robert A. Maguire',
#  'Arlene Mosel, Blair Lent',
#  'Yevgeny Zamyatin, Clarence Brown',
#  'Brian Froud, Alan Lee',
#  'Henning Mankell, Steven T. Murray',
#  'James Patterson, Keith David, Anthony Heald',
#  'Carl Sagan, Ann Druyan',
#  'Margaret Weis, Tracy Hickman',
#  'Brian K. Vaughan, Fiona Staples',
#  'JeanDominique Bauby, Jeremy Leggatt',
#  'Bill OReilly, Martin Dugard',
#  'Umberto Eco, William Weaver',
#  'James Patterson, Maxine Paetro',
#  'Stieg Larsson, Reg Keeland',
#  'Johann Wolfgang von Goethe, Burton Pike',
#  'Angie Sage, Mark Zug',
#  'سعود السنعوسي, Saud Alsanousi',
#  'Dava Sobel, Neil Armstrong',
#  'Johann Wolfgang von Goethe, Peter Salm',
#  'Joe Hill, Gabriel Rodríguez',
#  'J.R.R. Tolkien, Christopher Tolkien, Alan Lee',
#  'Richard Atwater, Florence Atwater, Robert Lawson',
#  'E.B. White, Fred Marcellino',
#  'Thomas J. Stanley, William D. Danko',
#  'Laura Ingalls Wilder, Garth Williams',
#  'George Selden, Garth Williams',
#  'William S. Burroughs, Oliver  Harris, Allen Ginsberg',
#  'Roger Fisher, William Ury, Bruce Patton',
#  'KrishnaDwaipayana Vyasa, Simon Brodbeck, Juan Mascaró',
#  'Paul Auster, Art Spiegelman',
#  'Friedrich Nietzsche, R.J. Hollingdale, Michael Tanner',
#  'Mark Owen, Kevin Maurer',
#  'Richard Bachman, Stephen King',
#  'Neil Gaiman, Matt Wagner, George Pratt, Dick Giordano, Kelley Jones, P. Craig Russell, Mike Dringenberg, Malcolm Jones III, Todd Klein, Harlan Ellison',
#  'James Patterson, Andrew Gross',
#  'Kami Garcia, Margaret Stohl',
#  'Ovid, David Raeburn, Denis Feeney',
#  'Bo Hampton, Tracey Hampton, Washington Irving',
#  'Colleen Hoover, Tarryn Fisher',
#  'Richard Lancelyn Green, Ronald Knox, Julian Symons, Various',
#  'E.M. Forster, Oliver Stallybrass, Pankaj Mishra',
#  'Stephen King, Jae Lee',
#  'James Howe, Deborah Howe, Alan Daniel',
#  'Jussi AdlerOlsen, Lisa Hartford',
#  'Frank Miller, Lynn Varley',
#  'Jo Nesbø, Don Bartlett',
#  'Nobuhiro Watsuki, Kenichiro Yagi',
#  'Jack Welch, Suzy Welch',
#  'Jean de Brunhoff, Merle S. Haas',
#  'Marjane Satrapi, Anjali Singh',
#  'Julia Child, Simone Beck, Louisette Bertholle',
#  'Kazue Kato, John Werry',
#  'Else Holmelund Minarik, Maurice Sendak',
#  'Holly Black, Tony DiTerlizzi',
#  'Robert Greene, Joost Elffers',
#  'Susanna Kearsley, Rosalyn Landor',
#  'Hubert Selby Jr., Darren Aronofsky, Richard Price',
#  'Władysław Szpilman, Anthea Bell',
#  'Geoffrey Crayon, Washington Irving, William L. Hedges',
#  'David Wilkerson, John Sherrill, Elizabeth Sherrill',
#  'Charlotte Brontë, A.S. Byatt, Μαρία Λαϊνά, Ignes Sodre',
#  'Stephen King, Peter Straub',
#  'Neil Gaiman, Andy Kubert, Richard Isanove, Peter Sanderson',
#  'Haruki Murakami, 村上 春樹',
#  'Paulo Coelho, Alan R. Clarke',
#  'Lee Child, Dick Hill',
#  'Grant Morrison, Frank Quitely',
#  'Elena Ferrante, Ann Goldstein',
#  'Anthony Robbins, Tony Robbins, Frederick L. Covan',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Henry Cloud, John Townsend',
#  'Philip Roth, Luca Marinelli',
#  'John C. Maxwell, Zig Ziglar',
#  'James Patterson, Maxine Paetro',
#  'Edgar Rice Burroughs, John Seelye',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Louis Sachar, Joel Schick',
#  'Julie Orringer, Arthur Morey',
#  'Thomas Hardy, Keith Wilson',
#  'Angie Sage, Mark Zug',
#  'Roald Dahl, Quentin Blake',
#  'Nicholas D. Kristof, Sheryl WuDunn',
#  'Daniel Handler, Maira Kalman',
#  'Shirley Jackson, Jonathan Lethem',
#  'Richard Wright, Jerry W. Ward Jr.',
#  'James D. Bradley, Ron Powers',
#  'A.A. Milne, Ernest H. Shepard',
#  'Lance Armstrong, Sally Jenkins',
#  'Christopher Yost, Orson Scott Card, Pasqual Ferry, Frank DArmata',
#  'Karuho Shiina, Tomo Kimura',
#  'Nina George, Simon Pare',
#  'Alistair MacLean, Clint Willis',
#  'Liu Cixin, Ken Liu',
#  'Mark Millar, Kilian Plunkett, Andrew Robinson, Walden Wong, Dave Johnson',
#  'Benjamin Franklin, Lewis Leary',
#  'Audrey Wood, Don    Wood',
#  'Italo Calvino, William Weaver',
#  'A.N. Roquelaure, Anne Rice',
#  'Stendhal, Roger Gard',
#  'Alvin Schwartz, Stephen Gammell',
#  'Pablo Neruda, W.S. Merwin, Cristina García',
#  'Thomas More, Paul Turner',
#  'Pseudonymous Bosch, Gilbert Ford',
#  'Dai Sijie, Ina Rilke',
#  'Roald Dahl, Quentin Blake',
#  'Betty MacDonald, Alexandra Boiger',
#  'CLAMP, Anthony Gerard',
#  'Alan Moore, Kevin ONeill',
#  'Euripides, Rex Warner',
#  'Brian K. Vaughan, Fiona Staples',
#  'James Patterson, Maxine Paetro',
#  'Warren Ellis, Darick Robertston, Garth Ennis',
#  'James Patterson, Gabrielle Charbonnet',
#  'Jean Craighead George, John Schoenherr',
#  'Umberto Eco, Girolamo De Michele, Alastair McEwen',
#  'Amanda Lindhout, Sara Corbett',
#  'Robert M. Edsel, Bret Witter',
#  'Mark Millar, John Romita Jr., Rob Liefeld',
#  'Immaculée Ilibagiza, Steve Erwin',
#  'Koushun Takami, Yuji Oniki',
#  'Terry Pratchett, Stephen Baxter',
#  'Steven Pressfield, Robert McKee',
#  'Larry Niven, Jerry Pournelle',
#  'W. Somerset Maugham, Benjamin DeMott, Maeve Binchy',
#  'A.A. Milne, Ernest H. Shepard',
#  'Vicki Myron, Bret Witter',
#  'Margret Rey, H.A. Rey',
#  'Raina Telgemeier, Gurihiru',
#  'Joseph Campbell, Bill Moyers',
#  'Frank W. Abagnale, Stan Redding',
#  'Scott Snyder, Greg Capullo, Jonathan Glapion',
#  'Milan Kundera, Aaron Asher',
#  'Edwin A. Abbott, Banesh Hoffmann',
#  'Erich Fromm, Peter D. Kramer, Rainer Funk',
#  'Neil Gaiman, Shawn McManus, Colleen Doran, Bryan Talbot, George Pratt, Stan Woch, Dick Giordano, Todd Klein',
#  'Margaret Weis, Tracy Hickman',
#  'Carl Bernstein, Bob Woodward',
#  'George Eliot, A.S. Byatt',
#  'Michelle Rowen, Richelle Mead',
#  'Robert Frost, Edward Connery Lathem',
#  'Åsne Seierstad, Ingrid Christopherson',
#  'Harold Bloom, Terry Southern, David H. Goldsmith, James Lundquist, Lawrence R. Broer, Peter J. Reed, Loree Rackstraw, William S. Doxey, Jerome Klinkowitz, Richard Giannone, John L. Simons, Leonard Mustazza, Zoltan Ab diNagy, Peter Freese, Wendy B. Faris',
#  'Beverly Cleary, Alan Tiegreen',
#  'Alexander Pushkin, James E. Falen',
#  'Amie Kaufman, Meagan Spooner',
#  'P.C. Cast, Kristin Cast',
#  'Carolyn Keene, Russell H. Tandy, Sara Paretsky',
#  'Hugh Lofting, Michael Hague',
#  'Isabel Allende, Nick Caistor, Amanda Hopkinson',
#  'D.H. Lawrence, Geoff Dyer',
#  'Robert T. Kiyosaki, Sharon L. Lechter',
#  'Camilla Läckberg, Steven T. Murray',
#  'Laura Joffe Numeroff, Felicia Bond',
#  'Franz Kafka, Jason Baker, Donna Freed',
#  'Unknown, Burton Raffel, Neil D. Isaacs',
#  'Edgar Allan Poe, Byron Glaser, Bill D. Fountain',
#  'Leonardo da Vinci, H. Anna Suh',
#  'Orhan Pamuk, Erdağ M. Göknar',
#  'Neil Gaiman, Chris Bachalo, Mark Buckingham, Tori Amos',
#  'Richard Paige, Dean Koontz',
#  'Young Kim, Stephenie Meyer',
#  'Samuel Taylor Coleridge, Gustave Doré',
#  'Robert Munsch, Michael Martchenko',
#  'Neil Gaiman, Jill Thompson, Vince Locke, Peter Straub',
#  'Hermann Hesse, Ursule Molinaro',
#  'Neil Gaiman, Bryan Talbot, Stan Woch, P. Craig Russell, Shawn McManus, John Watkiss, Jill Thompson, Duncan Eagleson, Kent Williams, Todd Klein',
#  'Charles Dickens, Helen Small, Stephen Wall',
#  'Radwa Ashour, رضوى عاشور',
#  'Michael Rosen, Helen Oxenbury',
#  'James Patterson, Howard Roughan',
#  'Edgar Allan Poe, Philip Pullman',
#  'Graham Greene, Robert  Stone',
#  'James Patterson, Maxine Paetro',
#  'Nicholas Sparks, Micah Sparks',
#  'Jorge Luis Borges, Anthony Kerrigan, Anthony Bonner',
#  'Chip Heath, Dan Heath',
#  'Mikhail Lermontov, Paul Foote',
#  'Orhan Pamuk, Maureen Freely',
#  'James Patterson, Michael Ledwidge',
#  'James Patterson, Michael Ledwidge',
#  'Nora Roberts, Angela Dawe',
#  'Jalaluddin Rumi, Coleman Barks',
#  'Brian K. Vaughan, Fiona Staples',
#  'Jack Canfield, Mark Victor Hansen',
#  'Brian Froud, Terry Windling',
#  'Stephen King, Bernie Wrightson',
#  'Anne Brontë, Angeline Goreau',
#  'A.P.J. Abdul Kalam, Arun Tiwari',
#  'L.J. Smith, Kevin Williamson, Julie Plec',
#  'Marjorie Flack, Kurt Wiese',
#  'Laura Ingalls Wilder, Garth Williams',
#  'Alfred Bester, Neil Gaiman',
#  'Augustine of Hippo, Henry Chadwick, Albert Cook Outler',
#  'أحلام مستغانمي, Ahlam Mosteghanemi',
#  'J.K. Rowling, Mary GrandPré',
#  'Holly Black, Cassandra Clare',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Elena Ferrante, Ann Goldstein',
#  'Hisaya Nakajo, David Ury',
#  'Atul Gawande, Susanne KuhlmannKrieg',
#  'Roland Barthes, Richard Howard',
#  'Michael Buckley, Peter Ferguson',
#  'Terry Pratchett, Stephen Briggs',
#  'Derek Landy, Tom Percival',
#  'Charles Dickens, Michael Slater',
#  'Terry Pratchett, Stephen Briggs',
#  'Albert Camus, Justin OBrien',
#  'Elizabeth Gaskell, Pam Morris',
#  'Primo Levi, Stuart J. Woolf, Philip Roth',
#  'Jules Verne, Caleb Carr, Jordan Stump',
#  'Carolyn Jessop, Laura Palmer',
#  'Marcus Buckingham, Curt Coffman',
#  'Thornton Wilder, Donald Margulies, Tappan Wilder',
#  'Jane Yolen, John Schoenherr',
#  'Fyodor Dostoyevsky, Constance Garnett, Gary Saul Morson',
#  'Jo Nesbø, Don Bartlett',
#  'Sylvia Plath, Ted Hughes',
#  'John Steinbeck, Susan Shillinglaw',
#  'Zoe Sugg, Siobhan Curham',
#  'Neil Gaiman, Marc Hempel, Richard Case, DIsraeli, Teddy Kristiansen, Glyn Dillon, Charles Vess, Dean Ormston, Kevin Nowlan, Todd Klein, Frank McConnell',
#  'Neil Gaiman, Mike Allred, Gary Amaro, Mark Buckingham, David Giordano, Tony Harris, Steve Leialoha, Vince Locke, Shea Anton Pensa, Alec Stevens, Bryan Talbot, John Watkiss, Todd Klein, Michael Zulli, Stephen King',
#  'Hans Christian Andersen, Jerry Pinkney',
#  'Graham Greene, Monica Ali',
#  'Felix Salten, Barbara Cooney',
#  'Herodotus, Aubrey de Sélincourt, John M. Marincola',
#  'Stephen R. Covey, A. Roger Merrill, Rebecca R. Merrill',
#  'Michael Chabon, Hans Hermann',
#  'Paolo Giordano, Shaun Whiteside',
#  'Neil Gaiman, Skottie Young',
#  'G. Willow Wilson, Adrian Alphona',
#  'Guillermo del Toro, Chuck Hogan',
#  'Francis Chan, Danae Yankoski',
#  'Rainer Maria Rilke, Reginald Snell, Franz Xaver Kappus',
#  'Charles Baudelaire, Richard Howard',
#  'PierreAmbroise Choderlos de Laclos, Douglas Parmée',
#  'Han Kang, Deborah     Smith',
#  'Franz Kafka, Mark Harman, Regaip Minareci, Şerif Yeşilbucak',
#  'Kimon Nicolaides, Mamie Harmon',
#  'Marcel Proust, Simon Vance, Lydia Davis',
#  'Don    Wood, Audrey Wood',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Naoki Higashida, K.A. Yoshida, David Mitchell',
#  'W.B. Yeats, Richard J. Finneran',
#  'Haruki Murakami, Jay Rubin, Alfred Birnbaum',
#  'Kerry Patterson, Joseph Grenny, Ron McMillan, Al Switzler, Stephen R. Covey',
#  'Robert Kirkman, Tony Moore, Charlie Adlard, Cliff Rathburn',
#  'Thomas Hobbes, C.B. Macpherson',
#  'Rob Thomas, Jennifer Graham',
#  'Danny Sugerman, Jerry Hopkins',
#  'Marguerite Henry, Wesley Dennis',
#  'William Gibson, Bruce Sterling',
#  'Brennan Manning, Michael W. Smith, Rich Mullins',
#  'Jonas Jonasson, Rachel WillsonBroyles',
#  'Shannon Hale, James Noel Smith',
#  'Edith Hamilton, Steele Savage',
#  'Eric Shanower, Skottie Young, L. Frank Baum',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'James Patterson, Michael Ledwidge',
#  'Rick Riordan, Gordon Korman, Peter Lerangis, Jude Watson',
#  'Dodie Smith, Michael Dooling',
#  'Joseph Delaney, Patrick  Arrasmith',
#  'Neil Gaiman, Michael Zulli, Jon J. Muth, Charles Vess, Mikal Gilmore',
#  'Bill OReilly, Martin Dugard',
#  'Douglas Preston, Lincoln Child',
#  'Benjamin Graham, Jason Zweig, Warren Buffett',
#  'William Shakespeare, John Jowett',
#  'Cassandra Clare, Sarah Rees Brennan, Maureen Johnson, Cassandra Jean',
#  'Banana Yoshimoto, Megan Backus',
#  'James Patterson, Peter de Jonge',
#  'Charles Dickens, Mark Ford',
#  'JeanJacques Rousseau, Maurice Cranston',
#  'Alexander Hamilton, James Madison, John Jay, PhiloPublius, Clinton Rossiter, Charles R. Kessler',
#  'Elena Ferrante, Ann Goldstein',
#  'Sarah Blake, Orlagh Cassidy',
#  'Ed Catmull, Amy Wallace',
#  'Frida Kahlo, Carlos Fuentes, Sarah M. Lowe',
#  'Douglas Preston, Lincoln Child',
#  'Lars Kepler, Ann Long',
#  'Tommy Lee, Vince Neil, Nikki Sixx, Neil Strauss, Mick Mars, Tommy Lee',
#  'Theodore Dreiser, Richard R. Lingeman',
#  'Amie Kaufman, Jay Kristoff',
#  'Susan Hill, John Lawrence',
#  'Colleen Hoover, Tarryn Fisher',
#  'Ian Rankin, Mircea Pricăjan',
#  'Robert Kirkman, Charlie Adlard',
#  'Lewis Carroll, John Tenniel',
#  'H.P. Lovecraft, August Derleth, Robert Bloch',
#  'H.P. Lovecraft, S.T. Joshi',
#  'Felicia Day, Joss Whedon',
#  'James Patterson, Michael Ledwidge',
#  'Matt Fraction, David Aja, Javier Pulido, Matt Hollingsworth, Chris Eliopoulos, Alan Davis',
#  'Jeph Loeb, Jim Lee, Scott Williams, Alex Sinclair, Richard Starkings',
#  'Haruki Murakami, Jay Rubin',
#  'Jodi Picoult, Samantha van Leer',
#  'Henry David Thoreau, W.S. Merwin',
#  'Erin Watt, Elle Kennedy, Jen Frederick',
#  'Patricia C. Wrede, Peter de Sève',
#  'Rachel Caine, Cynthia Holloway',
#  'James Patterson, NaRae Lee',
#  'Lene Kaaberbøl, Agnete Friis',
#  'Plato, Christopher Gill',
#  'Stella Gibbons, Lynne Truss, Roz Chast',
#  'Peter Høeg, Tiina Nunnally',
#  'Jeph Loeb, Tim Sale',
#  'Al Perkins, Eric Gurney',
#  'Juan Rulfo, Margaret Sayers Peden, Susan Sontag',
#  'T.S. Eliot, Michael North',
#  'Heather Cocks, Jessica  Morgan',
#  'Dave Barry, Ridley Pearson, Greg Call',
#  'Kohta Hirano, Duane Johnson',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Dean Koontz, Kevin J. Anderson, Scott Brick',
#  'Miyamoto Musashi, Victor Harris',
#  'Aristotle, J.A.K. Thomson, Jonathan Barnes, Hugh Tredennick',
#  'Richard Bachman, Stephen King',
#  'Trenton Lee Stewart, Diana Sudyka',
#  'William Shakespeare, Barbara A. Mowat, Paul Werstine',
#  'Knut Hamsun, George Egerton',
#  'Brian Azzarello, Lee Bermejo',
#  'Sergei Lukyanenko, Andrew Bromfield',
#  'Pierre Boulle, Xan Fielding',
#  'Katsura Hoshino, Mayumi Kobayashi',
#  'Ian Caldwell, Dustin Thomason',
#  'Gene Luen Yang, Bryan Konietzko, Michael Dante DiMartino, Dave Marshall, Gurihiru',
#  'Legs McNeil, Gillian McCain',
#  'George Orwell, Lionel Trilling',
#  'George R.R. Martin, Gary Gianni',
#  'Joss Whedon, Georges Jeanty',
#  'Mikhail Bulgakov, Mirra Ginsburg, Mikhail Bulgakov',
#  'Kurt Busiek, Alex Ross',
#  'Jay Asher, Carolyn Mackler',
#  'Christopher Moore, Oliver Wyman',
#  'Ina Garten, Melanie Acevedo',
#  'Kathy Reichs, Brendan Reichs',
#  'Laura Schroff, Alex Tresniowski, Valerie Salembier',
#  'P.C. Cast, Kristin Cast',
#  'Orson Scott Card, Aaron Johnston',
#  'Bryan Lee OMalley, Steve Buccellato',
#  'Alan Moore, Eddie Campbell, Pete Mullins',
#  'Sigmund Freud, James Strachey, Peter Gay',
#  'Joss Whedon, John Cassaday',
#  'Mariko Tamaki, Jillian Tamaki',
#  'Fyodor Dostoyevsky, Richard Pevear, Larissa Volokhonsky',
#  'Fyodor Dostoyevsky, Christian Redl, Philip Dossick, Emanuela Guercetti, MichelleIrène Brudny, Richard Pevear, Norman Dietz, Donald Fanger, coderati, Boris de Schlœzer, Larissa Volokhonsky',
#  'Andrew Williamson, Andrew Williamson',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Stephen Hawking, Leonard Mlodinow',
#  'Emily Bleeker, Dan John Miller',
#  'Aeschylus, Robert Fagles, William Bedell Stanford',
#  'Jon Stewart, Rory Albanese, Kevin Bleyer, Rich Bloomquist, Steve Bodow, Tim Carvell, Wyatt Cenac, Hallie Haglund, J.R. Havlan, David Javerbaum, Elliott Kalan, Josh Lieb, Sam Means, Jo Miller, John Oliver, Daniel Radosh, Jason Ross',
#  'Brother Andrew, Elizabeth Sherrill, John Sherrill',
#  'Lili St. Crow, Lilith Saintcrow',
#  'Malika Oufkir, Michèle Fitoussi',
#  'Mark Millar, Steve McNiven, Dexter Vines, Morry Hollowell',
#  'Kim Carpenter, John R. Perry, Krickitt Carpenter',
#  'CLAMP, William Flanagan',
#  'Oscar Wilde, Inga Moore',
#  'Bryan Lee OMalley, Nathan Fairbairn',
#  'Joseph Murphy, Ian McMahan',
#  'Esther Forbes, Lynd Ward',
#  'Ernesto Che Guevara, Aleida Guevara March',
#  'Roberto Bolaño, Natasha Wimmer',
#  'Stefan Zweig, Joel Rotenberg, Hans Hausmann, Dirk Muller, Peter Gay, Willy TrenkTrebitsch, Mario Adorf, Gert Westphal',
#  'Jo Nesbø, Charlotte Barslund',
#  'Margaret Weis, Tracy Hickman',
#  'Arkady Strugatsky, Boris Strugatsky, Antonina W. Bouis, Antonina W. Bouis, Theodore Sturgeon',
#  'Jack Kerouac, Aram Saroyan',
#  'Arturo PérezReverte, Sonia Soto',
#  'Beverly Cleary, Paul O. Zelinsky',
#  'Mary OHara, Dave Blossom',
#  'Philippa Gregory, Mirjana Valent',
#  'Henrik Ibsen, William Archer',
#  'Jo Nesbø, Don Bartlett',
#  'P.C. Cast, Kristin Cast',
#  'أحلام مستغانمي, Ahlam Mosteghanemi',
#  'Thomas Malory, Keith Baines, Robert Graves',
#  'Douglas Preston, Lincoln Child',
#  'Anton Chekhov, Richard Pevear, Larissa Volokhonsky',
#  'Karen Kingsbury, Gary Smalley',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Noel Streatfeild, Diane Goode',
#  'Ayn Rand, Leonard Peikoff',
#  'Russell Hoban, Lillian Hoban',
#  'Cece Bell, David Lasky',
#  'Robert Kirkman, Charlie Adlard',
#  'Plato, G.M.A. Grube, John M. Cooper',
#  'Thucydides, Rex Warner, Moses I. Finley',
#  'Jorge Luis Borges, Donald A. Yates, James E. Irby, André Maurois',
#  'Drew Daywalt, Oliver Jeffers',
#  'Katie J. Davis, Beth Clark',
#  'Thomas Mann, John E. Woods',
#  'Jack Canfield, Janet Switzer',
#  'Alaa Al Aswany, علاء الأسواني',
#  'V.E. Schwab, Victoria Schwab',
#  'Haruki Murakami, Philip Gabriel, Jay Rubin',
#  'Patricia C. Wrede, Peter de Sève',
#  'Wes  Moore, Tavis Smiley',
#  'Naoko Takeuchi, 武内 直子',
#  'Sarah Vowell, Katherine Streeter',
#  'Giovanni Boccaccio, G.H. McWilliam',
#  'Jorge Luis Borges, Andrew Hurley',
#  'Rick Riordan, Haley Riordan',
#  'Neil Patrick Harris, David Javerbaum, Antony Hare',
#  'Salman Rushdie, Paul Birkbeck',
#  'Nikos Kazantzakis, Νίκος Καζαντζάκης',
#  'William H. Armstrong, James Barkley',
#  'Lawrence M. Krauss, Richard Dawkins',
#  'Slash, Anthony Bozza',
#  'Gene Luen Yang, Bryan Konietzko, Michael Dante DiMartino, Gurihiru',
#  'JeanPaul Sartre, Hazel E. Barnes, Mary Warnock, Richard Eyre',
#  'Rachel Carson, Linda Lear, Edward O. Wilson',
#  'Scott Westerfeld, Keith Thompson',
#  'Morgan Rhodes, Michelle Rowen',
#  'Esther Hicks, Jerry Hicks, Wayne W. Dyer',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Henry Fielding, Thomas Keymer, Alice Wakely',
#  'Matthew Inman, The Oatmeal',
#  'Haruki Murakami, Ted Goossen',
#  'Diana L. Paxson, Marion Zimmer Bradley',
#  'Per Petterson, Anne Born',
#  'Doug Moench, Chuck Dixon, Jim Aparo, Norm Breyfogle, Graham Nolan, Jim Balent',
#  'Stephen King, Willem Dafoe',
#  'John Fante, Charles Bukowski',
#  'Philip Pullman, Jacob Grimm, Wilhelm Grimm',
#  'Aristophanes, Sarah Ruden',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Joss Whedon, Brett Matthews, Will Conrad',
#  'Eugene B. Sledge, Paul Fussell',
#  'Brian K. Vaughan, Pia Guerra, José Marzán Jr., Paul Chadwick',
#  'Karma Wilson, Jane Chapman',
#  'Brian Jacques, Gary Chalk',
#  'Thomas Hardy, Alexander Theroux',
#  'Michael Crichton, Richard   Preston',
#  'JeanPaul Sartre, Stuart Gilbert, Lionel Abel',
#  'Nathaniel Hawthorne, Robert S. Levine',
#  'W.E.B. Du Bois, Donald B. Gibson, Monica W. Elbert',
#  'Hannah  Green, Joanne Greenberg',
#  'Marguerite Duras, Barbara Bray, Maxine Hong Kingston',
#  'Graham Greene, John Updike',
#  'Edward Bloor, Danny De Vito',
#  'Bryan Burrough, John Helyar',
#  'David Fishelson, Aaron Leichter, Max Brod, Franz Kafka',
#  'Catherynne M. Valente, Ana Juan',
#  'Douglas Preston, Lincoln Child',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Hermann Hesse, Richard Winston, Clara Winston, Theodore Ziolkowski',
#  'Gerald Durrell, Helma Lapiņa',
#  'Stephen King, Robin A.H. Waterfield',
#  'Carl Sagan, Ann Druyan',
#  'LouisFerdinand Céline, Ralph Manheim, William T. Vollmann',
#  'Dean Koontz, Keith Szarabajka',
#  'Holly Black, Tony DiTerlizzi',
#  'René Descartes, Donald A. Cress',
#  'Douglas Preston, Lincoln Child',
#  'Anthony Robbins, Kenneth H. Blanchard, Jason Winters',
#  'Douglas Preston, Lincoln Child',
#  'Marilyn Manson, Neil Strauss',
#  'José Saramago, Margaret Jull Costa',
#  'Fredrik Backman, Henning Koch, سمانه پرهیزکاری',
#  'Rudyard Kipling, Edward Said',
#  'Immanuel Kant, Paul Guyer, Allen W. Wood',
#  'Rien Poortvliet, Wil Huygen',
#  'Rebecca Housel, J. Jeremy Wisnewski, William Irwin',
#  'Alexandre Dumas fils, David Coward',
#  'Stephen C. Lundin, Harry Paul, John Christensen, Kenneth H. Blanchard',
#  'Vi Keeland, Penelope Ward',
#  'J.D. Robb, Susan Ericksen',
#  'Michel Houellebecq, Frank Wynne',
#  'Giorgio Vasari, Julia Conway Bondanella, Peter Bondanella',
#  'Dmitry Glukhovsky, M. David Drevs',
#  'Robert Henri, Forbes Watson, Margery A. Ryerson',
#  'Holly Black, Tony DiTerlizzi',
#  'Ram Dass, Richard Alpert',
#  'James Patterson, Andrew Gross',
#  'A.N. Roquelaure, Anne Rice',
#  'Joe Hill, Christopher Golden',
#  'Edward Eager, N.M. Bodecker',
#  'Thich Nhat Hanh, Arnold Kotler, Dalai Lama XIV',
#  'Jim Starlin, Jim Aparo, Mike DeCarlo',
#  'Charlotte Brontë, Lucasta Miller, collaborative, Jessica Cox',
#  'Bill Willingham, Mark Buckingham, Craig Hamilton, Steve Leialoha, P. Craig Russell',
#  'Lee Child, Dick Hill',
#  'Plato, James J. Helm',
#  'Joni Eareckson Tada, Joe Musser',
#  'Margaret Weis, Tracy Hickman',
#  'Colleen Hoover, Tarryn Fisher',
#  'Anya Seton, Philippa Gregory',
#  'René Goscinny, JeanJacques Sempé',
#  'Harold G. Moore, Joseph L. Galloway',
#  'Rick Riordan, Tk',
#  'Eric Van Lustbader, Robert Ludlum',
#  'Franz Kafka, Nahum N. Glatzer, John Updike, Willa Muir, Edwin Muir, Tania Stern, James Stern, Ernst Kaiser, Eithne Wilkins',
#  'Isa Chandra Moskowitz, Terry Hope Romero',
#  'Margaret Weis, Tracy Hickman',
#  'Elissa Wall, Lisa Pulitzer',
#  'Ed Brubaker, Doug Mahnke, Patrick Zircher, Aaron Sowd, Steve Bird',
#  'Trenton Lee Stewart, Del Roy',
#  'Anton Chekhov, Tom    Murphy',
#  'J.R.R. Tolkien, Christopher Tolkien',
#  'أحلام مستغانمي, Ahlam Mosteghanemi',
#  'Patricia C. Wrede, Peter de Sève',
#  'James Patterson, Howard Roughan',
#  'Neil Gaiman, Chris Riddell',
#  'A.N. Roquelaure, Anne Rice',
#  'Gregory Maguire, Douglas Smith',
#  'Molière, Martin Sorrell',
#  'Ivan Goncharov, Stephen Pearl, Galya Diment',
#  'Po Bronson, Ashley Merryman',
#  'Raymond E. Feist, Janny Wurts',
#  'John Grisham, Richard Thomas',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Jessica Anthony, Rodrigo Corral',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Naguib Mahfouz, نجيب محفوظ',
#  'Isaac Asimov, Robert Silverberg',
#  'Eric Knight, Marguerite Kirmse',
#  'T. Colin Campbell, Thomas M. Campbell II',
#  'Julia Donaldson, Axel Scheffler',
#  'Sui Ishida, 石田 スイ',
#  'Jo Nesbø, Don Bartlett',
#  'G.K. Chesterton, Jonathan Lethem',
#  'Douglas Preston, Mario Spezi',
#  'Terry Pratchett, Paul Kidby',
#  'Joe Hill, Gabriel Rodríguez',
#  'Beverly Cleary, Alan Tiegreen',
#  'Julio Cortázar, Gregory Rabassa',
#  'Paulo Coelho, Margaret Jull Costa',
#  'Holly Black, Tony DiTerlizzi',
#  'Ozzy Osbourne, Chris Ayres',
#  'Stephanie Perkins, Holly Black, Ally Carter, Matt de la Pena, Gayle Forman, Jenny Han, David Levithan, Kelly Link, Myra McEntire, Rainbow Rowell, Laini Taylor, Kiersten White',
#  'Richard Bachman, Stephen King',
#  'Émile Zola, Roger Pearson',
#  'J. Lynn, Jennifer L. Armentrout',
#  'Isabel Allende, Margaret Sayers Peden',
#  'Robert Kirkman, Charlie Adlard, Cliff Rathburn',
#  'Michel Foucault, Alan Sheridan, Thomas Mathiesen, Walter Seitter, Drago Braco Rotar',
#  'Arina Tanemura, Tomo Kimura',
#  'Raymond E. Feist, Michael Avon Oeming, Bryan J.L. Glass, Ryan Stegman',
#  'David Eddings, Leigh Eddings',
#  'Tim LaHaye, Jerry B. Jenkins',
#  'Italo Calvino, Archibald Colquhoun',
#  'Stephenie Meyer, Young Kim',
#  'D.C. Talk, The Voice of the Martyrs',
#  'Jo Nesbø, Don Bartlett',
#  'Yuu Watase, Yuji Oniki',
#  'George MacDonald, Arthur Hughes',
#  'Roger Zelazny, Sönmez Güven',
#  'Roald Dahl, Quentin Blake',
#  'James Patterson, Michael Ledwidge',
#  'Joan Didion, David Thomson',
#  'Paulo Coelho, Alan R. Clarke',
#  'Joseph Delaney, Patrick  Arrasmith',
#  'Simone de Beauvoir, H.M. Parshley, Deirdre Bair',
#  'Margaret Weis, Tracy Hickman',
#  'Brian K. Vaughan, Pia Guerra, Goran Sudžuka, José Marzán Jr.',
#  ...]

# %%
authors_list = b['authors'].apply(lambda x: [a for a in x.split(', ')] if ',' in x else x)
authors_list.head()
# Out:
# 0                  Suzanne Collins
# 1    [J.K. Rowling, Mary GrandPré]
# 2                  Stephenie Meyer
# 3                       Harper Lee
# 4              F. Scott Fitzgerald
# Name: authors, dtype: object

# %%
splitted_authors = authors_list.apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True)
splitted_authors.name = 'authors'
splitted_authors.head()
# Out:
# 0    Suzanne Collins
# 1       J.K. Rowling
# 1      Mary GrandPré
# 2    Stephenie Meyer
# 3         Harper Lee
# Name: authors, dtype: object

# %%
#remove previous author column and join the new splitted authors
b = b.drop('authors', axis=1).join(splitted_authors)

# %%
# Take the first author for each book and remove the rest
b = b.drop_duplicates(subset='book_id', keep='first')

# %%
#author with most books
book_count_real = b['authors'].value_counts()
book_count_real.head()
book_count_real.to_csv('book_count_real.csv')

# %% [markdown]
# Now, instead of Stephen King, we found James Patterson is actually the author with the most books!

# %%
#visualize
plt.figure(figsize=(14,6))
sns.barplot(x=book_count_real.head(10).values, 
            y=book_count_real.head(10).index,
           palette = 'viridis')
plt.title('Author with most books', weight='bold', fontsize=20)
plt.xlabel('Number of titles', fontsize=14)
plt.ylabel('Authors', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('mostbookauthor.png', dpi=600, bbox_inches="tight", format='png')
plt.show()

# %% [markdown]
# #### 9. who's the most popular author?

# %%
popular_author = b.groupby('authors')['ratings_count'].sum().sort_values(ascending = False)
popular_author.head(5)
popular_author.to_csv('popular_author.csv')

# %%
#visualize
plt.figure(figsize=(14,6))
sns.barplot(x=popular_author.head(10).values, 
            y=popular_author.head(10).index,
           palette = 'Blues_r')
plt.title('Popular Author', weight='bold', fontsize=20)
plt.xlabel('Number of ratings', fontsize=14)
plt.ylabel('Authors', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('mostbookauthor.png', dpi=600, bbox_inches="tight", format='png')
plt.show()

# %%
b['authors'].value_counts()['J.K. Rowling']
# Out:
# 20

# %% [markdown]
# Although James Patterson is the author with max boks but he's not the one who has the most ratings.
# J.K Rowing is the most ratings author with his 20 books in dataset.

# %% [markdown]
# #### 10. author has good ratings book

# %%
# Let's check authors with biggest number of rates (total number for all books)
high_rating_author = b.groupby('authors')['average_rating'].mean().sort_values(ascending = False)
high_rating_author.head(5)
high_rating_author.to_csv('high_rated_author.csv')

# %% [markdown]
# #### 10. What Genre dominates the data?

# %%
g=[]
b.genres.apply(lambda x: g.append(x) if ','in x else [])
g[:6]
# Out:
# ['youngadult, fiction, fantasy, sciencefiction, romance',
#  'fantasy, fiction, youngadult, classics',
#  'youngadult, fantasy, romance, fiction, paranormal',
#  'classics, fiction, historicalfiction, youngadult',
#  'classics, fiction, historicalfiction, romance',
#  'youngadult, romance, fiction, contemporary']

# %%
#insert splitted genres list in every row
genres_list = b['genres'].apply(lambda x: [g for g in x.split(', ')] if ',' in x else x)
genres_list.head()
# Out:
# 0    [youngadult, fiction, fantasy, sciencefiction,...
# 1             [fantasy, fiction, youngadult, classics]
# 2    [youngadult, fantasy, romance, fiction, parano...
# 3    [classics, fiction, historicalfiction, youngad...
# 4      [classics, fiction, historicalfiction, romance]
# Name: genres, dtype: object

# %%
splitted_genres = genres_list.apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True)
splitted_genres.name = 'genres'
splitted_genres.head()
# Out:
# 0        youngadult
# 0           fiction
# 0           fantasy
# 0    sciencefiction
# 0           romance
# Name: genres, dtype: object

# %%
#remove previous genre column and join the new splitted genre
book_genres = b.drop('genres', axis=1).join(splitted_genres)
book_genres.to_csv('book_genres.csv')

# %%
x = book_genres['genres']
y = book_genres['average_rating']
#rank the genre based on number of books
genres_rank = book_genres.genres.value_counts()

#visualize
plt.figure(figsize=(20,10))
sns.barplot(x=genres_rank.head(10).values,
            y=genres_rank.head(10).index,
            palette = 'Blues_r')
plt.title('Popular genres', weight='bold', fontsize=20)
plt.xlabel('Count', fontsize=16)
plt.ylabel('Genres', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig('populargenres.png', dpi=600, bbox_inches="tight", format='png')
plt.show()

# %% [markdown]
# We can see that the majority (around 80%) of the books here are included in fiction books. The second rank goes to fantasy followed by romance. The difference between the first and second ranks is more than half. If you use a filtering method based on genre similarities, it is very unlikely that the engine will recommend non-fiction books.

# %% [markdown]
# #### Export Data

# %% [markdown]
# After making some changes to the data, we can now save our clean data and use it in the book recommendation system.

# %%
# b.to_csv('fInal_Data.csv')
